# %%
# !pip install --upgrade youtube-dl
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 5.1 MB/s
# ...

# %%
#youtube 영상 정보 받아오기
from youtube_dl import YoutubeDL

link = "https://www.youtube.com/playlist?list=PLVPcL0FVGV17GE8XGrRSLEOlJ8MAJkXZE"
ydl = YoutubeDL()
ydl.add_default_info_extractors()


info = ydl.extract_info(link,download=False)
# Out:
# [youtube:tab] PLVPcL0FVGV17GE8XGrRSLEOlJ8MAJkXZE: Downloading webpage
# [download] Downloading playlist: 🌟별사장님 노래 🌟
# [youtube:tab] Downloading page 1
# [youtube:tab] playlist 🌟별사장님 노래 🌟: Downloading 103 videos
# [download] Downloading video 1 of 103
# [youtube] jtr8y3xfs3Q: Downloading webpage
# [download] Downloading video 2 of 103
# [youtube] m_6jMwRUuBg: Downloading webpage
# [download] Downloading video 3 of 103
# [youtube] u4QRG6PSSJs: Downloading webpage
# [download] Downloading video 4 of 103
# [youtube] akggvnWYDfU: Downloading webpage
# [download] Downloading video 5 of 103
# [youtube] JsDR3ATrjWg: Downloading webpage
# [download] Downloading video 6 of 103
# [youtube] R86CThyxhB4: Downloading webpage
# [download] Downloading video 7 of 103
# [youtube] v-5hlxFSLCE: Downloading webpage
# [download] Downloading video 8 of 103
# [youtube] 5ANhk5cLiF0: Downloading webpage
# [download] Downloading video 9 of 103
# [youtube] xxSKPDinbHA: Downloading webpage
# ...

# %%
info

# %%
singer = info['uploader']
title = info['title']
url = info['webpage_url']

# %%
singer
# Out:
# '천영성'

# %%
title = info['title']
url = info['webpage_url']

# %%
# 설치(20.08 코랩 기준)
# !pip install Selenium
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver
# 한글 폰트 설치
# !apt-get install -y fonts-nanum*
# Out:
# ...
#      |████████████████████████████████| 904 kB 5.0 MB/s
# ...
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# ...

# %%
from selenium import webdriver

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless') #내부 창을 띄울 수 없으므로 설정
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# %%
from bs4 import BeautifulSoup
import time

#html_sources = []
#for url in url_list:
driver = webdriver.Chrome('chromedriver', chrome_options=chrome_options) 

driver.get(url) 
last_page_height = driver.execute_script("return document.documentElement.scrollHeight") 
for i in range(50):
  driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);") 
  time.sleep(3.0) 
  new_page_height = driver.execute_script("return document.documentElement.scrollHeight") 
  if new_page_height == last_page_height: 
    break 
last_page_height = new_page_height 
html_source = driver.page_source
driver.close() 


soup = BeautifulSoup(html_source, 'lxml')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
youtube_comments = soup.select('#content-text')

# %%
# !pip install customized_konlpy
# Out:
# ...
#      |████████████████████████████████| 881 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 448 kB 50.4 MB/s
# ...
#      |████████████████████████████████| 19.4 MB 124 kB/s
# ...
#      |████████████████████████████████| 86 kB 5.7 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-tcdrcp4m
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-tcdrcp4m
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2255830 sha256=6027465a54c5903393ea097b801fb726e7c014bf390e2eae1c9839772a0ccd75
#   Stored in directory: /tmp/pip-ephem-wheel-cache-iunxx_7u/wheels/9b/93/81/a2a7dc8c66ede5bf30634d20635f32b95eac7ca2ea8844058b
# Successfully built pykospacing
# ...

# %%
from pykospacing import Spacing
from hanspell import spell_checker
spacing = Spacing()

# %%
print(youtube_comments)
# Out:
# [<yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">와....진짜 제가 정말 좋아하는곡인데... 이렇게 알흠다운 목소리로 불러주시다니 ㅠㅠ 감사합니다!! 종종 와서 듣겠습니다!</yt-formatted-string>, <yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">Perfeita (:</yt-formatted-string>, <yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines=""><span class="style-scope yt-formatted-string" dir="auto">진짜 왜 이렇게 아련하게 생기셨지...</span><span class="style-scope yt-formatted-string" dir="auto">
# </span><span class="style-scope yt-formatted-string" dir="auto">눈망울이 진짜 꽃사슴같애..</span><span class="style-scope yt-formatted-string" dir="auto">
# </span><span class="style-scope yt-formatted-string" dir="auto">호소력도 괜히 더 짙게 들리고..</span><span class="style-scope yt-formatted-string" dir="auto">
# ...

# %%
# !pip install git+https://github.com/ssut/py-hanspell.git
# Out:
# ...
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-zci1mfsd
#   Running command git clone -q https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-zci1mfsd
# ...
#   Created wheel for py-hanspell: filename=py_hanspell-1.1-py3-none-any.whl size=4868 sha256=335fa15a5c26b70256f4e5f71cb641dc9d8cdb21dfdfc8f205c7590fb4afd8ba
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h2p1ko8p/wheels/ab/f5/7b/d4124bb329c905301baed80e2ae45aa14e824f62ebc3ec2cc4
# Successfully built py-hanspell
# ...

# %%
comment_list = []
for comment in youtube_comments:
  comment_list.append(spacing(comment.text))

# %%
from ckonlpy.tag import Twitter

twi = Twitter()
twi.add_dictionary('첫소절','Noun')
twi.add_dictionary('소절','Noun')
twi.add_dictionary('곡','Noun')
twi.add_dictionary('끝판왕','Noun')
twi.add_dictionary('처음','Noun')
twi.add_dictionary('별은','Noun')
twi.add_dictionary('조회수','Noun')
twi.add_dictionary('은방울','Noun')
twi.add_dictionary('최애곡','Noun')
twi.add_dictionary('여신','Noun')
twi.add_dictionary('은비','Noun')
twi.add_dictionary('워너비','Noun')

comment_nouns = []
for comment in comment_list:
  comment_nouns.append(twi.nouns(comment))
# Out:
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
for comment in comment_nouns:
  print(comment)
# Out:
# ['진짜', '제', '정말', '아하', '곡', '알흠', '다운', '목소리', '주시', '감사', '종종']
# []
# ['진짜', '왜', '생기', '셨', '눈망울', '진짜', '꽃사슴', '애', '호소', '력도', '더', '별', '거', '해', '예뽀']
# []
# ['진짜', '여태', '까지', '적', '음색', '앞', '열심', '활동', '해주시', '더', '번창']
# []
# []
# ['가성', '사람', '처음', '봄']
# ['권진아', '끝', '제발', '진짜', '꼭', '어요', '진짜', '사람', '목소리', '인', '것', '요', '제발', '부탁']
# ['마음', '간절', '애절', '감정', '지네']
# ['진짜', '진짜', '목소리', '은', '비', '더', '노래', '처럼', '뭔가', '더더', '욱', '기도', '오랜만', '정말', '감정', '표현', '면서', '노래', '사람', '앞', '계속', '팬', '진짜', '애', '정합']
# ['오마이', '걸', '유아', '목소리', '나', '고', '아이유', '목소리', '나', '고', '느낌', '신기하', '권진아', '분', '끝', '노래', '요']
# ['목소리', '편안', '듣기', '거', '이', '채널', '끝판왕']
# ['노래', '감정', '게', '실력', '실력', '가성', '활용', '능력', '감정', '전달', '정확', '발음', '등']
# ['팬미팅', '바람', '걸', '라이브', '귀가', '녹', '아버', '렸', '후회', '참고', '때', '이', '뻤습니', '역시', '정식', '가수', '어서', '인지', '클라스']
# ...

# %%
import re 
import numpy as np
