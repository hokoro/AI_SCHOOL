# %% [markdown]
# # 3 - B: Training a Word2Vec Model
#
# ## 목표
# - 한국어 단어 임베딩 벡터를 Word2Vec을 학습시켜 얻어봅시다.
# - 학습데이터로는 [네이버 영화리뷰 데이터](https://drive.google.com/file/d/1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS/view?usp=sharing)를 사용해볼 것입니다.

# %%
# install the libraries needed
# !pip3 install gensim  # word2vec 훈련을 위해
# !pip3 install pandas # 데이터 시각화를 위해
# !pip3 install konlpy  # 한국어 형태소 분석을 위해
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.1.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.4 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 69.2 MB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.1 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
# import the libraries needed
from gensim.models.word2vec import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec  # 매 에폭마다의 로스를 확인하기 위해.
from konlpy.tag import Okt
from typing import List
import pandas as pd
from tqdm import tqdm
import gdown
# --- Word2Vec 훈련이 진행되는 과정을 모니터링 하기 위해, 모든 로깅 레벨을 INFO로 올려줍니다. --- #
from sys import stdout
import logging
logging.basicConfig(stream=stdout, level=logging.DEBUG)

# %%
# --- 데이터 다운로드를 위한 코드; 수정하지 말아주세요! --- #
NAVER_REVIEWS_TSV_URL = "https://drive.google.com/u/0/uc?id=1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS&export=download"
NAVER_REVIEWS_TSV = "./naver_reviews.tsv"
# 드라이브에 업로드한 (data/naver_reviews.tsv) 파일을 로컬에 다운로드
gdown.download(url=NAVER_REVIEWS_TSV_URL, output=NAVER_REVIEWS_TSV, quiet=False)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): drive.google.com:443
# DEBUG:urllib3.connectionpool:https://drive.google.com:443 "GET /u/0/uc?id=1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS&export=download HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): doc-0o-08-docs.googleusercontent.com:443
# DEBUG:urllib3.connectionpool:https://doc-0o-08-docs.googleusercontent.com:443 "GET /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/2oqvfu5e43fdvcqs1br1rr0irh0d4v26/1629697575000/11244659521636006499/*/1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS?e=download HTTP/1.1" 200 None
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS&export=download
# To: /content/naver_reviews.tsv
# 19.5MB [00:00, 78.0MB/s]
# './naver_reviews.tsv'

# %%
# 네이버 영화 데이터를 pandas dataframe으로 로드합니다. 구분자가 \t 인 tsv 파일을 읽어야 하니, sep="\t"로 넣어줍니다.
reviews_df = pd.read_csv(NAVER_REVIEWS_TSV, sep="\t") #tsv file tab 을 기준으로 구분하는 문자 이다 .

# %%
# (id, 리뷰, 긍정=1/부정=0)으로 구성된 데이터입니다.
reviews_df.head(10)  # 상위 10개 문서 출력
# Out:
#          id                                           document  label
# 0   8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1   8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2   4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3   9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4  10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1
# 5   2190435                      사랑을 해본사람이라면 처음부터 끝까지 웃을수 있는영화      1
# 6   9279041                                   완전 감동입니다 다시봐도 감동      1
# 7   7865729                        개들의 전쟁2 나오나요? 나오면 1빠로 보고 싶음      1
# 8   7477618                                                  굿      1
# 9   9250537                                     바보가 아니라 병 쉰 인듯      1

# %%
# 각 모든 데이터 중에, 결측치가 하나라도 존재하는지 확인해볼게요.
# df.info(): https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html
print(reviews_df.isnull().values.any())
reviews_df.info()
# Out:
# True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        200000 non-null  int64
#  1   document  199992 non-null  object
#  2   label     200000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.6+ MB

# %%
# document 컬럼을 보아하니, 결측치가 조금 있습니다. 결측치를 제거하기 위해 dropna()를 사용하겠습니다.
# df.dropna() 문서: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html
# how = any 로 설정할 경우? null인 컬럼이 하나라도 있으면 해당 row를 드랍.
# how = all 로 설정할 경우? 모든 컬럼이 null 일 경우에만 해당 row를 드랍.
reviews_df = reviews_df.dropna(how="any")
print(reviews_df.isnull().values.any())
reviews_df.info()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# False
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199992 entries, 0 to 199999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        199992 non-null  int64
#  1   document  199992 non-null  object
#  2   label     199992 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 6.1+ MB

# %%
# ---- 전체 리뷰문서 토크나이징을 진행합니다 --- # 
okt = Okt()  # okt 형태소 분석기를 토크나이저로 사용합니다.
corpus: List[List[str]] = list()
# 모든 데이터를 다 토크나이즈를 하기에는 시간이 많이 걸릴 것입니다. 
# 앞 10만개 정도만 선택하여 토크나이즈를 해보도록 하겠습니다.
reviews_df = reviews_df[:100000] 
for sent in tqdm(reviews_df['document'], "tokenization in progress..."):
    # 토큰화를 진행할 때, 어근을 추출하여 토큰화 동시에 정규화를 해줍니다 (e.g. 밝은 -> 밝다)
    tokens = okt.morphs(sent, stem=True)  #stem = True 어간도 같이 추출 한다.
    corpus.append(tokens)
# Out:
# tokenization in progress...: 100%|██████████| 100000/100000 [04:19<00:00, 385.83it/s]

# %%
# --- 전처리된 말뭉치 확인 --- #
# 대부분의 단어들이 정규화되어, "-다"로 끝나는 것을 확인해볼 수 있습니다. 
for tokens in corpus[:10]:
  print(tokens)
# Out:
# ['어리다', '때', '보고', '지금', '다시', '보다', '재밌다', 'ㅋㅋ']
# ['디자인', '을', '배우다', '학생', '으로', ',', '외국', '디자이너', '와', '그', '들', '이', '일군', '전통', '을', '통해', '발전', '하다', '문화', '산업', '이', '부럽다', '.', '사실', '우리나라', '에서도', '그', '어렵다', '시절', '에', '끝', '까지', '열정', '을', '지키다', '노라노', '같다', '전통', '이', '있다', '저', '와', '같다', '사람', '들', '이', '꿈', '을', '꾸다', '이루다', '나가다', '수', '있다', '것', '에', '감사하다', '.']
# ['폴리스스토리', '시리즈', '는', '1', '부터', '뉴', '까지', '버리다', '하나', '도', '없다', '..', '최고', '.']
# ['오다', '..', '연기', '가', '진짜', '개', '쩔다', '..', '지루하다', '생각', '하다', '몰입', '하다', '보다', '..', '그렇다', '이렇다', '진짜', '영화', '지']
# ['안개', '자욱하다', '밤하늘', '에', '뜨다', '있다', '초승달', '같다', '영화', '.']
# ['사랑', '을', '해보다', '사람', '이', '라면', '처음', '부터', '끝', '까지', '웃다', '있다', '영화']
# ['완전', '감동', '이다', '다시', '보다', '감동']
# ['개', '들', '의', '전쟁', '2', '나오다', '?', '나오다', '1', '빠', '로', '보고', '싶다']
# ['굿']
# ['바보', '가', '아니다', '병', '쉰', '이다']

# %%
# --- 워드 투 벡터의 훈련상황을 모니터링하기 위해, 메 에폭마다 모델의 로스 (error)를 출력해볼 수 있습니다. --- #
# 이를 위해서 Callback이라는 객체를 사용할 수 있습니다. 
# https://stackoverflow.com/a/54891714
class LossCallBack(CallbackAny2Vec):
    def __init__(self):
        self.epoch = 0
        self.losses = list()  # collect losses here
        self.losses.append(0.0)

    def on_epoch_end(self, model):
        """
        이 함수는 매 에폭의 마지막 단계에 호출됩니다.
        """
        # get_ latest_training_loss는 현재까지의 cumulative loss를 출력합니다.
        loss = model.get_latest_training_loss()
        self.epoch += 1
        self.losses.append(loss)
        # 현재까지의 축적된 로스의 총합을 리포트
        print('Cumulative loss after epoch {}: {}'.format(self.epoch, loss))
        # 바로 이전 로스와의 차이도 리포트
        print('Offset to previous loss: {}'.format(str(self.losses[-1] - self.losses[-2])))

# %%
# --- TODO 1 --- # 
# Word2Vec의 객체를 생성하면, 바로 Word2Vec 모델의 학습이 진행됩니다. 
# Word2Vec 클래스 문서를 참고하여: https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec
# Word2Vec 모델학습을 시작해보세요!
# 하이퍼파라미터는 다음과 같이 설정해주세요:
# alpha (learning rate) = 0.01
# window (윈도우의 길이) = 6
# min_count (학습할 단어의 최소 빈도수) = 3
# sg (skipgram 사용여부) =  1
# iter (에폭) = 50
# compute_loss (매 에폭마다 로스 계산) = True
# callbacks (매 에폭마다 호출할 것들) = (LossCallBack(),)
model = Word2Vec(sentences=corpus #말뭉치
                 ,alpha=0.01, #learning rate
                 window=6,  #윈도우의 크기 (ngrams 의 n)
                 min_count=3, #embedding 을 구한 단어의 최소 빈도수 
                 sg=1, #sg = 0 cbow sg=1 skipgram
                 iter=50,  #epoch
                 compute_loss=True, #매 에폭 마다 LOSS 계산 
                 negative = 5,
                 callbacks=(LossCallBack(),)) #매 에폭마다 수행할 일을 넣어줄수 있다.
# ------------ #
# Out:
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 139027 words, keeping 12618 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 281908 words, keeping 18275 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #30000, processed 420918 words, keeping 22279 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #40000, processed 560545 words, keeping 25579 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #50000, processed 700594 words, keeping 28656 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #60000, processed 841566 words, keeping 31336 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #70000, processed 982494 words, keeping 33685 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #80000, processed 1124238 words, keeping 35890 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #90000, processed 1263421 words, keeping 37919 word types
# INFO:gensim.models.word2vec:collected 39823 word types from a corpus of 1402998 raw words and 100000 sentences
# INFO:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:gensim.models.word2vec:effective_min_count=3 retains 16154 unique words (40% of original 39823, drops 23669)
# INFO:gensim.models.word2vec:effective_min_count=3 leaves 1374103 word corpus (97% of original 1402998, drops 28895)
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 39823 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 55 most-common words
# INFO:gensim.models.word2vec:downsampling leaves estimated 1077343 word corpus (78.4% of prior 1374103)
# INFO:gensim.models.base_any2vec:estimated required memory for 16154 words and 100 dimensions: 21000200 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.models.base_any2vec:training model with 3 workers on 16154 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=6
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 14.98% examples, 157613 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 30.62% examples, 161862 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 46.27% examples, 163408 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 62.70% examples, 163515 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 78.93% examples, 165336 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 94.64% examples, 165163 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 1 : training on 1402998 raw words (1077491 effective words) took 6.5s, 166243 effective words/s
# Cumulative loss after epoch 1: 5508904.0
# Offset to previous loss: 5508904.0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 14.98% examples, 152929 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 31.31% examples, 161974 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 47.02% examples, 161214 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 63.36% examples, 162216 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 79.61% examples, 163397 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 96.79% examples, 164258 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 2 : training on 1402998 raw words (1077101 effective words) took 6.5s, 165159 effective words/s
# Cumulative loss after epoch 2: 9575901.0
# Offset to previous loss: 4066997.0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 14.98% examples, 155290 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 31.31% examples, 162323 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 47.02% examples, 163699 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 63.42% examples, 163051 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 78.88% examples, 163573 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 94.64% examples, 164027 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 3 : training on 1402998 raw words (1077203 effective words) took 6.5s, 165234 effective words/s
# Cumulative loss after epoch 3: 12757804.0
# Offset to previous loss: 3181903.0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 14.98% examples, 158959 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 29.90% examples, 158289 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 45.54% examples, 159866 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 61.24% examples, 161113 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 76.83% examples, 162074 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 91.81% examples, 160693 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 4 : training on 1402998 raw words (1077288 effective words) took 6.6s, 162135 effective words/s
# Cumulative loss after epoch 4: 16218629.0
# Offset to previous loss: 3460825.0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 14.29% examples, 152289 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 30.59% examples, 159101 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 46.98% examples, 162665 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 62.70% examples, 163364 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 78.20% examples, 163840 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 93.92% examples, 164282 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 5 : training on 1402998 raw words (1076712 effective words) took 6.5s, 164388 effective words/s
# Cumulative loss after epoch 5: 19364508.0
# Offset to previous loss: 3145879.0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 14.98% examples, 161018 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 30.59% examples, 163126 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 46.27% examples, 163187 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 62.70% examples, 163113 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 78.93% examples, 164773 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 94.64% examples, 165312 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 6 : training on 1402998 raw words (1077386 effective words) took 6.5s, 165477 effective words/s
# Cumulative loss after epoch 6: 22670706.0
# Offset to previous loss: 3306198.0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 14.98% examples, 156737 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 30.62% examples, 160190 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 47.02% examples, 164388 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 63.38% examples, 163888 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 79.66% examples, 165239 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 96.06% examples, 165637 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 7 : training on 1402998 raw words (1077683 effective words) took 6.5s, 166598 effective words/s
# Cumulative loss after epoch 7: 25844212.0
# Offset to previous loss: 3173506.0
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 14.98% examples, 159752 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 29.90% examples, 158408 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 45.56% examples, 160635 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 61.23% examples, 160963 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 76.83% examples, 161449 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 92.54% examples, 162339 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 8 : training on 1402998 raw words (1077548 effective words) took 6.7s, 161972 effective words/s
# Cumulative loss after epoch 8: 28984246.0
# Offset to previous loss: 3140034.0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 14.27% examples, 151104 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 29.90% examples, 157818 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 45.58% examples, 158149 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 61.23% examples, 159616 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 76.78% examples, 161211 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 92.50% examples, 160814 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 9 : training on 1402998 raw words (1076846 effective words) took 6.6s, 162211 effective words/s
# Cumulative loss after epoch 9: 32107026.0
# Offset to previous loss: 3122780.0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 14.29% examples, 152259 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 29.87% examples, 155523 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 46.27% examples, 157930 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 62.69% examples, 160145 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 78.93% examples, 161377 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 94.61% examples, 161759 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 10 : training on 1402998 raw words (1076880 effective words) took 6.6s, 162998 effective words/s
# Cumulative loss after epoch 10: 34536068.0
# Offset to previous loss: 2429042.0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 15.71% examples, 154057 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 32.03% examples, 157919 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 48.45% examples, 161214 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 64.78% examples, 161923 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 80.34% examples, 162040 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 94.61% examples, 160415 words/s, in_qsize 6, out_qsize 1
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 11 : training on 1402998 raw words (1077614 effective words) took 6.6s, 162261 effective words/s
# Cumulative loss after epoch 11: 36320672.0
# Offset to previous loss: 1784604.0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 14.29% examples, 149248 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 30.62% examples, 159330 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 46.27% examples, 161845 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 62.69% examples, 164599 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 78.20% examples, 164063 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 93.92% examples, 163155 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 12 : training on 1402998 raw words (1077532 effective words) took 6.6s, 164435 effective words/s
# Cumulative loss after epoch 12: 38085260.0
# Offset to previous loss: 1764588.0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 14.98% examples, 154287 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 31.31% examples, 161100 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 47.00% examples, 161712 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 63.42% examples, 164724 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 78.20% examples, 163240 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 93.23% examples, 162544 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 43 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 13 : training on 1402998 raw words (1077109 effective words) took 6.6s, 164170 effective words/s
# Cumulative loss after epoch 13: 39900780.0
# Offset to previous loss: 1815520.0
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 14.31% examples, 143066 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 29.90% examples, 155408 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 45.54% examples, 158857 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 61.23% examples, 160040 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 77.50% examples, 161735 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 93.22% examples, 162387 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 14 : training on 1402998 raw words (1077589 effective words) took 6.7s, 161979 effective words/s
# Cumulative loss after epoch 14: 41620832.0
# Offset to previous loss: 1720052.0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 14.98% examples, 151539 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 30.59% examples, 159091 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 44.83% examples, 157148 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 60.52% examples, 158784 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 76.11% examples, 160080 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 91.81% examples, 160394 words/s, in_qsize 6, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 43 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 15 : training on 1402998 raw words (1077250 effective words) took 6.7s, 161303 effective words/s
# Cumulative loss after epoch 15: 43278572.0
# Offset to previous loss: 1657740.0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 14.97% examples, 151867 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 30.62% examples, 155477 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 47.02% examples, 161296 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 63.38% examples, 161154 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 79.61% examples, 163909 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 94.64% examples, 162944 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 16 : training on 1402998 raw words (1076923 effective words) took 6.5s, 164634 effective words/s
# Cumulative loss after epoch 16: 44996080.0
# Offset to previous loss: 1717508.0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 15.71% examples, 157021 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 31.31% examples, 162336 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 47.02% examples, 161808 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 62.70% examples, 162853 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 78.93% examples, 162506 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 94.61% examples, 163513 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 17 : training on 1402998 raw words (1077642 effective words) took 6.6s, 163929 effective words/s
# Cumulative loss after epoch 17: 46722288.0
# Offset to previous loss: 1726208.0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 14.29% examples, 152250 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 29.90% examples, 159939 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 45.54% examples, 162137 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 61.23% examples, 161103 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 76.78% examples, 162208 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 92.54% examples, 162972 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 18 : training on 1402998 raw words (1077509 effective words) took 6.6s, 163611 effective words/s
# Cumulative loss after epoch 18: 48426624.0
# Offset to previous loss: 1704336.0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 14.98% examples, 159730 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 30.60% examples, 161601 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 46.27% examples, 163866 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 61.97% examples, 163597 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 78.20% examples, 165896 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 93.23% examples, 164319 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 19 : training on 1402998 raw words (1077129 effective words) took 6.5s, 165552 effective words/s
# Cumulative loss after epoch 19: 50101948.0
# Offset to previous loss: 1675324.0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 15.71% examples, 158923 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 31.31% examples, 162890 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 47.73% examples, 163968 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 63.36% examples, 161538 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 78.93% examples, 161960 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 95.36% examples, 163187 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 20 : training on 1402998 raw words (1077287 effective words) took 6.6s, 164154 effective words/s
# Cumulative loss after epoch 20: 51804192.0
# Offset to previous loss: 1702244.0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 14.27% examples, 150097 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 30.62% examples, 159864 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 46.29% examples, 161055 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 62.70% examples, 162735 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 78.20% examples, 163132 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 94.64% examples, 162799 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 21 : training on 1402998 raw words (1077839 effective words) took 6.6s, 164357 effective words/s
# Cumulative loss after epoch 21: 53514156.0
# Offset to previous loss: 1709964.0
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 14.98% examples, 154429 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 31.31% examples, 163826 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 46.27% examples, 162370 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 61.97% examples, 162360 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 78.20% examples, 162403 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 94.64% examples, 163507 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 22 : training on 1402998 raw words (1077438 effective words) took 6.5s, 164742 effective words/s
# Cumulative loss after epoch 22: 55149052.0
# Offset to previous loss: 1634896.0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 15.02% examples, 154268 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 30.62% examples, 158953 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 47.02% examples, 163755 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 62.69% examples, 163875 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 78.93% examples, 164378 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 95.34% examples, 165862 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 23 : training on 1402998 raw words (1077003 effective words) took 6.5s, 165488 effective words/s
# Cumulative loss after epoch 23: 56840388.0
# Offset to previous loss: 1691336.0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 14.27% examples, 153154 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 30.59% examples, 162899 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 46.98% examples, 163594 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 61.97% examples, 162546 words/s, in_qsize 3, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 77.48% examples, 163392 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 93.92% examples, 164064 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 24 : training on 1402998 raw words (1077271 effective words) took 6.6s, 164424 effective words/s
# Cumulative loss after epoch 24: 58568224.0
# Offset to previous loss: 1727836.0
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 14.29% examples, 151036 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 29.90% examples, 159045 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 45.56% examples, 160649 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 61.97% examples, 161069 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 78.20% examples, 163085 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 94.64% examples, 164603 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 25 : training on 1402998 raw words (1077605 effective words) took 6.5s, 165505 effective words/s
# Cumulative loss after epoch 25: 60232452.0
# Offset to previous loss: 1664228.0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 14.98% examples, 159718 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 29.87% examples, 157449 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 45.56% examples, 160690 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 61.25% examples, 161599 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 77.48% examples, 162364 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 93.22% examples, 163138 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 26 : training on 1402998 raw words (1077469 effective words) took 6.6s, 163241 effective words/s
# Cumulative loss after epoch 26: 61905924.0
# Offset to previous loss: 1673472.0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 15.02% examples, 149530 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 30.62% examples, 154451 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 47.02% examples, 160404 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 62.70% examples, 161585 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 78.91% examples, 162978 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 93.95% examples, 162415 words/s, in_qsize 4, out_qsize 1
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 27 : training on 1402998 raw words (1076958 effective words) took 6.6s, 164170 effective words/s
# Cumulative loss after epoch 27: 63516744.0
# Offset to previous loss: 1610820.0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 15.02% examples, 152089 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 31.31% examples, 159254 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 47.73% examples, 161705 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 64.11% examples, 163700 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 79.61% examples, 164318 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 95.34% examples, 164546 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 44 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 28 : training on 1402998 raw words (1077324 effective words) took 6.5s, 165990 effective words/s
# Cumulative loss after epoch 28: 65213328.0
# Offset to previous loss: 1696584.0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 14.98% examples, 152825 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 31.31% examples, 160012 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 46.29% examples, 159203 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 61.95% examples, 159354 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 76.83% examples, 158785 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 93.22% examples, 160343 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 29 : training on 1402998 raw words (1077017 effective words) took 6.7s, 161140 effective words/s
# Cumulative loss after epoch 29: 66837372.0
# Offset to previous loss: 1624044.0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 14.98% examples, 155607 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 32.03% examples, 164096 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 48.44% examples, 165157 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 64.11% examples, 164417 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 79.61% examples, 164776 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 94.64% examples, 164041 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 30 : training on 1402998 raw words (1077578 effective words) took 6.6s, 164463 effective words/s
# Cumulative loss after epoch 30: 67140216.0
# Offset to previous loss: 302844.0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 14.98% examples, 159299 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 29.90% examples, 157891 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 47.02% examples, 163615 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 61.97% examples, 162903 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 78.20% examples, 161971 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 94.64% examples, 162998 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 31 : training on 1402998 raw words (1077533 effective words) took 6.6s, 163891 effective words/s
# Cumulative loss after epoch 31: 67179912.0
# Offset to previous loss: 39696.0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 15.02% examples, 152622 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 30.59% examples, 159284 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 46.29% examples, 160148 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 62.69% examples, 162686 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 78.93% examples, 162714 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 95.36% examples, 163842 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 32 : training on 1402998 raw words (1077477 effective words) took 6.5s, 165481 effective words/s
# Cumulative loss after epoch 32: 67220984.0
# Offset to previous loss: 41072.0
# INFO:gensim.models.base_any2vec:EPOCH 33 - PROGRESS: at 14.98% examples, 150450 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 33 - PROGRESS: at 31.31% examples, 157325 words/s, in_qsize 5, out_qsize 0
# ...
# Cumulative loss after epoch 39: 67509768.0
# Offset to previous loss: 42432.0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 14.98% examples, 154584 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 31.31% examples, 162972 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 47.02% examples, 162375 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 62.69% examples, 163293 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 77.50% examples, 162272 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 93.23% examples, 162629 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 40 : training on 1402998 raw words (1077233 effective words) took 6.6s, 163621 effective words/s
# Cumulative loss after epoch 40: 67549784.0
# Offset to previous loss: 40016.0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 14.31% examples, 148180 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 29.19% examples, 151908 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 45.56% examples, 156334 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 61.95% examples, 158516 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 78.93% examples, 160904 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 95.34% examples, 163016 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 41 : training on 1402998 raw words (1077325 effective words) took 6.6s, 163665 effective words/s
# Cumulative loss after epoch 41: 67592976.0
# Offset to previous loss: 43192.0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 15.02% examples, 151731 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 30.59% examples, 155296 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 47.02% examples, 162019 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 61.95% examples, 161325 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 77.51% examples, 161952 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 93.22% examples, 162763 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 50 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 42 : training on 1402998 raw words (1077319 effective words) took 6.6s, 163916 effective words/s
# Cumulative loss after epoch 42: 67635584.0
# Offset to previous loss: 42608.0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 14.29% examples, 149030 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 29.90% examples, 156582 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 45.54% examples, 159392 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 61.95% examples, 160997 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 77.48% examples, 162163 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 93.22% examples, 163060 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 43 : training on 1402998 raw words (1077084 effective words) took 6.6s, 164146 effective words/s
# Cumulative loss after epoch 43: 67679520.0
# Offset to previous loss: 43936.0
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 15.71% examples, 163535 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 31.31% examples, 165878 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 47.02% examples, 166665 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 61.23% examples, 162364 words/s, in_qsize 3, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 77.50% examples, 163627 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 93.22% examples, 163819 words/s, in_qsize 6, out_qsize 1
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 44 : training on 1402998 raw words (1077247 effective words) took 6.5s, 164580 effective words/s
# Cumulative loss after epoch 44: 67721408.0
# Offset to previous loss: 41888.0
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 14.98% examples, 147021 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 30.62% examples, 154098 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 46.27% examples, 156340 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 62.66% examples, 158507 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 77.50% examples, 158922 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 93.20% examples, 159679 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 45 : training on 1402998 raw words (1076735 effective words) took 6.7s, 161037 effective words/s
# Cumulative loss after epoch 45: 67766096.0
# Offset to previous loss: 44688.0
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 14.98% examples, 157886 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 30.59% examples, 158959 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 47.02% examples, 161860 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 64.11% examples, 164458 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 79.61% examples, 164485 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 96.06% examples, 165313 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 50 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 46 : training on 1402998 raw words (1077398 effective words) took 6.5s, 165880 effective words/s
# Cumulative loss after epoch 46: 67812960.0
# Offset to previous loss: 46864.0
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 15.02% examples, 154964 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 31.31% examples, 164179 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 47.73% examples, 163250 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 64.78% examples, 166168 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 80.34% examples, 166198 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 96.79% examples, 167101 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 47 : training on 1402998 raw words (1077469 effective words) took 6.5s, 166983 effective words/s
# Cumulative loss after epoch 47: 67858608.0
# Offset to previous loss: 45648.0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 15.71% examples, 155692 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 31.31% examples, 161402 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 47.73% examples, 164112 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 63.40% examples, 165115 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 78.93% examples, 165288 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 95.34% examples, 167100 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 48 : training on 1402998 raw words (1077932 effective words) took 6.5s, 166988 effective words/s
# Cumulative loss after epoch 48: 67900736.0
# Offset to previous loss: 42128.0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 14.98% examples, 157541 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 31.31% examples, 165100 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 47.02% examples, 162099 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 63.42% examples, 164213 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 78.93% examples, 163914 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 94.64% examples, 163785 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 49 : training on 1402998 raw words (1076670 effective words) took 6.5s, 164380 effective words/s
# Cumulative loss after epoch 49: 67942080.0
# Offset to previous loss: 41344.0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 14.98% examples, 153981 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 30.59% examples, 156324 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 47.02% examples, 159203 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 63.42% examples, 161440 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 78.93% examples, 162098 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 95.34% examples, 162569 words/s, in_qsize 6, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 50 : training on 1402998 raw words (1077266 effective words) took 6.6s, 163673 effective words/s
# Cumulative loss after epoch 50: 67986872.0
# Offset to previous loss: 44792.0
# INFO:gensim.models.base_any2vec:training on a 70149900 raw words (53865712 effective words) took 329.4s, 163541 effective words/s

# %%
model.wv.vocab
# Out:
# {'어리다': <gensim.models.keyedvectors.Vocab at 0x7f864dde7fd0>,
#  '때': <gensim.models.keyedvectors.Vocab at 0x7f864dde7050>,
#  '보고': <gensim.models.keyedvectors.Vocab at 0x7f864dde7ed0>,
#  '지금': <gensim.models.keyedvectors.Vocab at 0x7f864dde7d90>,
#  '다시': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3e10>,
#  '보다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3e50>,
#  '재밌다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3d90>,
#  'ㅋㅋ': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3150>,
#  '디자인': <gensim.models.keyedvectors.Vocab at 0x7f864dde7710>,
#  '을': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3f90>,
#  '배우다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3210>,
#  '학생': <gensim.models.keyedvectors.Vocab at 0x7f864ddd35d0>,
#  '으로': <gensim.models.keyedvectors.Vocab at 0x7f864ddd37d0>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3750>,
#  '외국': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3b10>,
#  '디자이너': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3ad0>,
#  '와': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3510>,
#  '그': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3090>,
#  '들': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3890>,
#  '이': <gensim.models.keyedvectors.Vocab at 0x7f864ddd32d0>,
#  '전통': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3cd0>,
#  '통해': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3110>,
#  '발전': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3a10>,
#  '하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3c50>,
#  '문화': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3810>,
#  '산업': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4410>,
#  '부럽다': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4ad0>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4e50>,
#  '사실': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4350>,
#  '우리나라': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4e10>,
#  '에서도': <gensim.models.keyedvectors.Vocab at 0x7f864ddc41d0>,
#  '어렵다': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4e90>,
#  '시절': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4dd0>,
#  '에': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4bd0>,
#  '끝': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4650>,
#  '까지': <gensim.models.keyedvectors.Vocab at 0x7f864c629e50>,
#  '열정': <gensim.models.keyedvectors.Vocab at 0x7f864c629510>,
#  '지키다': <gensim.models.keyedvectors.Vocab at 0x7f864c6291d0>,
#  '같다': <gensim.models.keyedvectors.Vocab at 0x7f864c629a50>,
#  '있다': <gensim.models.keyedvectors.Vocab at 0x7f864c629a90>,
#  '저': <gensim.models.keyedvectors.Vocab at 0x7f864c6298d0>,
#  '사람': <gensim.models.keyedvectors.Vocab at 0x7f864c629690>,
#  '꿈': <gensim.models.keyedvectors.Vocab at 0x7f864c629b50>,
#  '꾸다': <gensim.models.keyedvectors.Vocab at 0x7f864c629c10>,
#  '이루다': <gensim.models.keyedvectors.Vocab at 0x7f864c629b90>,
#  '나가다': <gensim.models.keyedvectors.Vocab at 0x7f864c629dd0>,
#  '수': <gensim.models.keyedvectors.Vocab at 0x7f864c629350>,
#  '것': <gensim.models.keyedvectors.Vocab at 0x7f864c6292d0>,
#  '감사하다': <gensim.models.keyedvectors.Vocab at 0x7f864c629810>,
#  '폴리스스토리': <gensim.models.keyedvectors.Vocab at 0x7f864c629190>,
#  '시리즈': <gensim.models.keyedvectors.Vocab at 0x7f864c629410>,
#  '는': <gensim.models.keyedvectors.Vocab at 0x7f864c629e90>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7f864c629990>,
#  '부터': <gensim.models.keyedvectors.Vocab at 0x7f864c6293d0>,
#  '뉴': <gensim.models.keyedvectors.Vocab at 0x7f864c629b10>,
#  '버리다': <gensim.models.keyedvectors.Vocab at 0x7f864c629450>,
#  '하나': <gensim.models.keyedvectors.Vocab at 0x7f864c6296d0>,
#  '도': <gensim.models.keyedvectors.Vocab at 0x7f864c629250>,
#  '없다': <gensim.models.keyedvectors.Vocab at 0x7f864c629d10>,
#  '..': <gensim.models.keyedvectors.Vocab at 0x7f864c629650>,
#  '최고': <gensim.models.keyedvectors.Vocab at 0x7f864c629c90>,
#  '오다': <gensim.models.keyedvectors.Vocab at 0x7f864c629d50>,
#  '연기': <gensim.models.keyedvectors.Vocab at 0x7f864c629790>,
#  '가': <gensim.models.keyedvectors.Vocab at 0x7f864c629cd0>,
#  '진짜': <gensim.models.keyedvectors.Vocab at 0x7f864c629bd0>,
#  '개': <gensim.models.keyedvectors.Vocab at 0x7f864c629a10>,
#  '쩔다': <gensim.models.keyedvectors.Vocab at 0x7f864c629f10>,
#  '지루하다': <gensim.models.keyedvectors.Vocab at 0x7f864c629ed0>,
#  '생각': <gensim.models.keyedvectors.Vocab at 0x7f864c629e10>,
#  '몰입': <gensim.models.keyedvectors.Vocab at 0x7f864c629d90>,
#  '그렇다': <gensim.models.keyedvectors.Vocab at 0x7f864c629950>,
#  '이렇다': <gensim.models.keyedvectors.Vocab at 0x7f864c629ad0>,
#  '영화': <gensim.models.keyedvectors.Vocab at 0x7f864c629910>,
#  '지': <gensim.models.keyedvectors.Vocab at 0x7f864c6294d0>,
#  '안개': <gensim.models.keyedvectors.Vocab at 0x7f864ea50b10>,
#  '밤하늘': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b990>,
#  '뜨다': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b7d0>,
#  '사랑': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b610>,
#  '해보다': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b910>,
#  '라면': <gensim.models.keyedvectors.Vocab at 0x7f864ea3bc50>,
#  '처음': <gensim.models.keyedvectors.Vocab at 0x7f864ea3bf50>,
#  '웃다': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b690>,
#  '완전': <gensim.models.keyedvectors.Vocab at 0x7f864ea3be90>,
#  '감동': <gensim.models.keyedvectors.Vocab at 0x7f864ea3ba90>,
#  '이다': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b650>,
#  '의': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b3d0>,
#  '전쟁': <gensim.models.keyedvectors.Vocab at 0x7f864ea3bd50>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7f864ea3bfd0>,
#  '나오다': <gensim.models.keyedvectors.Vocab at 0x7f864ea3bc90>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x7f864ea3bf90>,
#  '빠': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b810>,
#  '로': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b710>,
#  '싶다': <gensim.models.keyedvectors.Vocab at 0x7f864ea3bd10>,
#  '굿': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b4d0>,
#  '바보': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b890>,
#  '아니다': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b790>,
#  '병': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b390>,
#  '쉰': <gensim.models.keyedvectors.Vocab at 0x7f864ea3b450>,
#  '내': <gensim.models.keyedvectors.Vocab at 0x7f864eaaeb90>,
#  '나이': <gensim.models.keyedvectors.Vocab at 0x7f864ea7f410>,
#  '를': <gensim.models.keyedvectors.Vocab at 0x7f8679e16350>,
#  '나': <gensim.models.keyedvectors.Vocab at 0x7f864ddeecd0>,
#  '적': <gensim.models.keyedvectors.Vocab at 0x7f864ddee3d0>,
#  '하지만': <gensim.models.keyedvectors.Vocab at 0x7f864ddeed10>,
#  '훗날': <gensim.models.keyedvectors.Vocab at 0x7f864ddeedd0>,
#  '사하나': <gensim.models.keyedvectors.Vocab at 0x7f864ddeeed0>,
#  '하': <gensim.models.keyedvectors.Vocab at 0x7f864ddeefd0>,
#  '감정': <gensim.models.keyedvectors.Vocab at 0x7f864ddeee10>,
#  '완벽하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddee710>,
#  '이해': <gensim.models.keyedvectors.Vocab at 0x7f864ddeef10>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x7f864ddee1d0>,
#  '고질': <gensim.models.keyedvectors.Vocab at 0x7f864ddee890>,
#  '라니': <gensim.models.keyedvectors.Vocab at 0x7f864ddeec90>,
#  '무': <gensim.models.keyedvectors.Vocab at 0x7f864ddeeb50>,
#  '귀엽다': <gensim.models.keyedvectors.Vocab at 0x7f864ddee490>,
#  '능': <gensim.models.keyedvectors.Vocab at 0x7f864ddee410>,
#  '오페라': <gensim.models.keyedvectors.Vocab at 0x7f864c611ed0>,
#  '화': <gensim.models.keyedvectors.Vocab at 0x7f864c611e10>,
#  '라고': <gensim.models.keyedvectors.Vocab at 0x7f864c606690>,
#  '작품': <gensim.models.keyedvectors.Vocab at 0x7f864c5fbd50>,
#  '극단': <gensim.models.keyedvectors.Vocab at 0x7f864ddf9310>,
#  '평': <gensim.models.keyedvectors.Vocab at 0x7f864ddf92d0>,
#  '은': <gensim.models.keyedvectors.Vocab at 0x7f864ddf9790>,
#  '어쩔': <gensim.models.keyedvectors.Vocab at 0x7f864ddf9090>,
#  '듯': <gensim.models.keyedvectors.Vocab at 0x7f864ddf97d0>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7f864ddf9210>,
#  '반전': <gensim.models.keyedvectors.Vocab at 0x7f864ddf9190>,
#  '좋다': <gensim.models.keyedvectors.Vocab at 0x7f864ddf9750>,
#  '제': <gensim.models.keyedvectors.Vocab at 0x7f864de1f750>,
#  '^^': <gensim.models.keyedvectors.Vocab at 0x7f864de1f790>,
#  '평점': <gensim.models.keyedvectors.Vocab at 0x7f864de1f6d0>,
#  '왜': <gensim.models.keyedvectors.Vocab at 0x7f864de1fdd0>,
#  '낮다': <gensim.models.keyedvectors.Vocab at 0x7f864de1fa50>,
#  '긴장감': <gensim.models.keyedvectors.Vocab at 0x7f864de1fe90>,
#  '스릴': <gensim.models.keyedvectors.Vocab at 0x7f864de1fc50>,
#  '감': <gensim.models.keyedvectors.Vocab at 0x7f864de1fb10>,
#  '인데': <gensim.models.keyedvectors.Vocab at 0x7f864de1fad0>,
#  '전장': <gensim.models.keyedvectors.Vocab at 0x7f864de1f7d0>,
#  '에서': <gensim.models.keyedvectors.Vocab at 0x7f864de1f8d0>,
#  '느끼다': <gensim.models.keyedvectors.Vocab at 0x7f864de1f810>,
#  '공포': <gensim.models.keyedvectors.Vocab at 0x7f864de1ff90>,
#  '생생하다': <gensim.models.keyedvectors.Vocab at 0x7f864de1f950>,
#  '전': <gensim.models.keyedvectors.Vocab at 0x7f864de1fe50>,
#  '해주다': <gensim.models.keyedvectors.Vocab at 0x7f864de1f9d0>,
#  '네': <gensim.models.keyedvectors.Vocab at 0x7f864de1fa90>,
#  '터': <gensim.models.keyedvectors.Vocab at 0x7f864de1fa10>,
#  '랑': <gensim.models.keyedvectors.Vocab at 0x7f864de1f990>,
#  '소재': <gensim.models.keyedvectors.Vocab at 0x7f864de1fd50>,
#  '만': <gensim.models.keyedvectors.Vocab at 0x7f864de1f590>,
#  '뿐': <gensim.models.keyedvectors.Vocab at 0x7f864de1f650>,
#  '아무렇다': <gensim.models.keyedvectors.Vocab at 0x7f864de1f910>,
#  '관련': <gensim.models.keyedvectors.Vocab at 0x7f864de1fb50>,
#  '단연': <gensim.models.keyedvectors.Vocab at 0x7f864de1f5d0>,
#  '가면': <gensim.models.keyedvectors.Vocab at 0x7f864de1fbd0>,
#  '갈수록': <gensim.models.keyedvectors.Vocab at 0x7f864de1f690>,
#  '더욱': <gensim.models.keyedvectors.Vocab at 0x7f864de1f890>,
#  '빠지다': <gensim.models.keyedvectors.Vocab at 0x7f864de1f850>,
#  '드': <gensim.models.keyedvectors.Vocab at 0x7f864de1f610>,
#  '요': <gensim.models.keyedvectors.Vocab at 0x7f864de1f710>,
#  '밀회': <gensim.models.keyedvectors.Vocab at 0x7f864de1fc10>,
#  '화이팅': <gensim.models.keyedvectors.Vocab at 0x7f864de1fd90>,
#  '!!': <gensim.models.keyedvectors.Vocab at 0x7f864de1fcd0>,
#  '어': <gensim.models.keyedvectors.Vocab at 0x7f864de1ffd0>,
#  '없이': <gensim.models.keyedvectors.Vocab at 0x7f864de1ff50>,
#  '상당하다': <gensim.models.keyedvectors.Vocab at 0x7f864de1fd10>,
#  '수작': <gensim.models.keyedvectors.Vocab at 0x7f864de1fc90>,
#  '일본': <gensim.models.keyedvectors.Vocab at 0x7f864de1fed0>,
#  '10년': <gensim.models.keyedvectors.Vocab at 0x7f864de1fe10>,
#  '마음': <gensim.models.keyedvectors.Vocab at 0x7f864de1ff10>,
#  '들다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb1d0>,
#  '강렬하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb710>,
#  '임팩트': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb750>,
#  '일품': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb090>,
#  '오랜': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb250>,
#  '제대로': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbdd0>,
#  '되다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbb90>,
#  '범죄': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb510>,
#  '스릴러': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb110>,
#  '~': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb5d0>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x7f864ddcb8d0>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb390>,
#  '그저': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb450>,
#  '좋아하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb790>,
#  '마디': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb4d0>,
#  '말': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb150>,
#  '꺼내다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb050>,
#  '벅차다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb590>,
#  '밤': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb610>,
#  '잠': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb690>,
#  '설치다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb3d0>,
#  '크다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb7d0>,
#  '교복': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb490>,
#  '남다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb190>,
#  '션': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb810>,
#  '자': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb650>,
#  '이의': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbed0>,
#  '자국': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb550>,
#  '역시': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb850>,
#  '미처': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb410>,
#  '다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb2d0>,
#  '전하': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb350>,
#  '못': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb310>,
#  '한': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb890>,
#  '형태': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb6d0>,
#  '인': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbb50>,
#  '거': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbad0>,
#  '마지막': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbb10>,
#  '씬': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbbd0>,
#  '잊다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbc90>,
#  '강압': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbc10>,
#  '용서': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbd10>,
#  '세뇌': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbd50>,
#  '대한': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbe50>,
#  '비판': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbf10>,
#  '중세시대': <gensim.models.keyedvectors.Vocab at 0x7f864ddcba50>,
#  '명작': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbcd0>,
#  '이래': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbc50>,
#  '7시간': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbf90>,
#  '짜리': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbfd0>,
#  '영상': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbf50>,
#  '존재': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbe90>,
#  '죽다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbd90>,
#  '꼭': <gensim.models.keyedvectors.Vocab at 0x7f864ddcbe10>,
#  '한번': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb910>,
#  '아름답다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb950>,
#  '슬프다': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb990>,
#  'OST': <gensim.models.keyedvectors.Vocab at 0x7f864ddcb9d0>,
#  '제니퍼': <gensim.models.keyedvectors.Vocab at 0x7f864ddcba90>,
#  '코넬': <gensim.models.keyedvectors.Vocab at 0x7f864ddcba10>,
#  '리': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5050>,
#  '눈부시다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5090>,
#  '아역시절': <gensim.models.keyedvectors.Vocab at 0x7f864ddd50d0>,
#  '로버트': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5110>,
#  '드니': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5150>,
#  '장면': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5190>,
#  '정말': <gensim.models.keyedvectors.Vocab at 0x7f864ddd51d0>,
#  '가슴속': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5210>,
#  '영원하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5250>,
#  '기억': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5290>,
#  '어떻다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd52d0>,
#  '저런': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5310>,
#  '짓': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5350>,
#  '수가': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5390>,
#  'ㅡㅡ': <gensim.models.keyedvectors.Vocab at 0x7f864ddd53d0>,
#  '화나다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5410>,
#  '인간': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5450>,
#  '잠재': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5490>,
#  '악마': <gensim.models.keyedvectors.Vocab at 0x7f864ddd54d0>,
#  '성은': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5510>,
#  '여러': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5550>,
#  '시간': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5590>,
#  '과': <gensim.models.keyedvectors.Vocab at 0x7f864ddd55d0>,
#  '공간': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5610>,
#  '속': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5650>,
#  '해오다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5690>,
#  '다큐': <gensim.models.keyedvectors.Vocab at 0x7f864ddd56d0>,
#  '그것': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5710>,
#  '엉뚱하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5750>,
#  '광': <gensim.models.keyedvectors.Vocab at 0x7f8686cbba90>,
#  '재현': <gensim.models.keyedvectors.Vocab at 0x7f8676f82d10>,
#  '최고다': <gensim.models.keyedvectors.Vocab at 0x7f8676f82810>,
#  '동안': <gensim.models.keyedvectors.Vocab at 0x7f8676f82bd0>,
#  '쉬다': <gensim.models.keyedvectors.Vocab at 0x7f8676f82b90>,
#  '틈틈이': <gensim.models.keyedvectors.Vocab at 0x7f864c5f28d0>,
#  '잠도': <gensim.models.keyedvectors.Vocab at 0x7f864ddc4190>,
#  '줄이다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3a90>,
#  '여운': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3990>,
#  '실화': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3910>,
#  '여서': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3190>,
#  '충격': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3e90>,
#  '다시다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd36d0>,
#  '어디': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3b50>,
#  '일어나서': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3d10>,
#  '안되다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3850>,
#  '경': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3a50>,
#  '각심': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3dd0>,
#  '일': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3ed0>,
#  '깨우다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd3790>,
#  '존': <gensim.models.keyedvectors.Vocab at 0x7f864dde7f90>,
#  '쯤': <gensim.models.keyedvectors.Vocab at 0x7f864dde7150>,
#  '알다': <gensim.models.keyedvectors.Vocab at 0x7f864dde7e90>,
#  '되게': <gensim.models.keyedvectors.Vocab at 0x7f864dde7090>,
#  '봄': <gensim.models.keyedvectors.Vocab at 0x7f864dde7d10>,
#  '이정재': <gensim.models.keyedvectors.Vocab at 0x7f864dde7110>,
#  '이범수': <gensim.models.keyedvectors.Vocab at 0x7f864dde70d0>,
#  'ㅋㅋㅋㅋ': <gensim.models.keyedvectors.Vocab at 0x7f864dde7f10>,
#  '쩜': <gensim.models.keyedvectors.Vocab at 0x7f864dde7190>,
#  '친구': <gensim.models.keyedvectors.Vocab at 0x7f864dde71d0>,
#  '우정': <gensim.models.keyedvectors.Vocab at 0x7f864dde74d0>,
#  '매우': <gensim.models.keyedvectors.Vocab at 0x7f864dde7410>,
#  '굿굿굿': <gensim.models.keyedvectors.Vocab at 0x7f864dde7550>,
#  '또': <gensim.models.keyedvectors.Vocab at 0x7f864dde7510>,
#  '라': <gensim.models.keyedvectors.Vocab at 0x7f864dde7590>,
#  '제발': <gensim.models.keyedvectors.Vocab at 0x7f864dde7650>,
#  'ㅠㅠ': <gensim.models.keyedvectors.Vocab at 0x7f864dde7e10>,
#  '아': <gensim.models.keyedvectors.Vocab at 0x7f864dde77d0>,
#  '재미있다': <gensim.models.keyedvectors.Vocab at 0x7f864dde7850>,
#  '너무': <gensim.models.keyedvectors.Vocab at 0x7f864dde7890>,
#  '어울리다': <gensim.models.keyedvectors.Vocab at 0x7f864dde7210>,
#  '제이크': <gensim.models.keyedvectors.Vocab at 0x7f864dde7250>,
#  '질렌할': <gensim.models.keyedvectors.Vocab at 0x7f864dde73d0>,
#  '넌': <gensim.models.keyedvectors.Vocab at 0x7f864dde7690>,
#  '대체': <gensim.models.keyedvectors.Vocab at 0x7f864dde76d0>,
#  '뭐': <gensim.models.keyedvectors.Vocab at 0x7f864dde7910>,
#  '냐': <gensim.models.keyedvectors.Vocab at 0x7f864dde7950>,
#  '입가': <gensim.models.keyedvectors.Vocab at 0x7f864dde7990>,
#  '미소': <gensim.models.keyedvectors.Vocab at 0x7f864dde79d0>,
#  '원표': <gensim.models.keyedvectors.Vocab at 0x7f864dde75d0>,
#  '조연': <gensim.models.keyedvectors.Vocab at 0x7f864dde7a50>,
#  '젤': <gensim.models.keyedvectors.Vocab at 0x7f864dde7ad0>,
#  '많이': <gensim.models.keyedvectors.Vocab at 0x7f864dde7a90>,
#  '마치': <gensim.models.keyedvectors.Vocab at 0x7f864dde7b10>,
#  '바다': <gensim.models.keyedvectors.Vocab at 0x7f864dde7b50>,
#  '아쿠아리움': <gensim.models.keyedvectors.Vocab at 0x7f864dde7b90>,
#  '들어가다': <gensim.models.keyedvectors.Vocab at 0x7f864dde7bd0>,
#  '느낌': <gensim.models.keyedvectors.Vocab at 0x7f864dde7c10>,
#  '자녀': <gensim.models.keyedvectors.Vocab at 0x7f864dde7c50>,
#  '에게': <gensim.models.keyedvectors.Vocab at 0x7f864dde7750>,
#  '강추': <gensim.models.keyedvectors.Vocab at 0x7f864dde7790>,
#  '정의': <gensim.models.keyedvectors.Vocab at 0x7f864dde7610>,
#  '세우다': <gensim.models.keyedvectors.Vocab at 0x7f864dde7d50>,
#  '노동자': <gensim.models.keyedvectors.Vocab at 0x7f864dde7810>,
#  '이야기': <gensim.models.keyedvectors.Vocab at 0x7f864dde7290>,
#  '영': <gensim.models.keyedvectors.Vocab at 0x7f864dde7350>,
#  '화보': <gensim.models.keyedvectors.Vocab at 0x7f864dde72d0>,
#  '면': <gensim.models.keyedvectors.Vocab at 0x7f864dde7310>,
#  '브라질': <gensim.models.keyedvectors.Vocab at 0x7f864dde7390>,
#  '가다': <gensim.models.keyedvectors.Vocab at 0x7f864dde7450>,
#  '사라지다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5810>,
#  '난': <gensim.models.keyedvectors.Vocab at 0x7f864ddd57d0>,
#  '남자': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5790>,
#  '지만': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5850>,
#  '내내': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5890>,
#  '울리다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd58d0>,
#  '그리고': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5910>,
#  '두': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5950>,
#  '여배우': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5990>,
#  '멤버': <gensim.models.keyedvectors.Vocab at 0x7f864ddd59d0>,
#  '모두': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5a10>,
#  '기대': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5a50>,
#  '액션': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5a90>,
#  '런가': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5ad0>,
#  '겁나다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5b10>,
#  '흥미진진': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5b50>,
#  'ㄷㄷ': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5b90>,
#  '워낙': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5bd0>,
#  '격투씬': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5c10>,
#  'ㅋㅋㅋ': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5c50>,
#  '그냥': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5c90>,
#  '아무': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5cd0>,
#  '집': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5d10>,
#  '스마트': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5d50>,
#  '티비': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5d90>,
#  '뭔': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5dd0>,
#  '인지도': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5e10>,
#  '모르다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5e50>,
#  '암살': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5e90>,
#  '걍': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5ed0>,
#  '하여튼': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5f10>,
#  '인정': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5f50>,
#  'ㅆ': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5f90>,
#  '파르': <gensim.models.keyedvectors.Vocab at 0x7f864ddd5fd0>,
#  '년': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9050>,
#  '북한': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9090>,
#  '살': <gensim.models.keyedvectors.Vocab at 0x7f864ddd90d0>,
#  '하고': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9110>,
#  '목숨': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9150>,
#  '걸다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9190>,
#  '대한민국': <gensim.models.keyedvectors.Vocab at 0x7f864ddd91d0>,
#  '그거': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9210>,
#  '납득': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9250>,
#  '시키다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9290>,
#  '나불': <gensim.models.keyedvectors.Vocab at 0x7f864ddd92d0>,
#  '거려': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9310>,
#  '종북': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9350>,
#  '박평': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9390>,
#  '식': <gensim.models.keyedvectors.Vocab at 0x7f864ddd93d0>,
#  '틀다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9410>,
#  '그대': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9450>,
#  '여': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9490>,
#  '6월': <gensim.models.keyedvectors.Vocab at 0x7f864ddd94d0>,
#  '비': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9510>,
#  '내다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9550>,
#  '보이다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9590>,
#  '시작': <gensim.models.keyedvectors.Vocab at 0x7f864ddd95d0>,
#  '반갑다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9610>,
#  '얼굴': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9650>,
#  '주인공': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9690>,
#  '넘다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd96d0>,
#  '매력': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9710>,
#  '이구': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9750>,
#  '유쾌하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9790>,
#  '~~': <gensim.models.keyedvectors.Vocab at 0x7f864ddd97d0>,
#  '용이': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9810>,
#  'ㅎ': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9850>,
#  '요즘': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9890>,
#  '아이돌': <gensim.models.keyedvectors.Vocab at 0x7f864ddd98d0>,
#  '배우': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9910>,
#  '해먹': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9950>,
#  '정도': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9990>,
#  '잘': <gensim.models.keyedvectors.Vocab at 0x7f864ddd99d0>,
#  '게': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9a10>,
#  '봣는대': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9a50>,
#  '어디서': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9a90>,
#  '받다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9ad0>,
#  '잇다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9b10>,
#  '조': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9b50>,
#  '탱고': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9b90>,
#  '음악': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9bd0>,
#  '밀려오다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9c10>,
#  '평생': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9c50>,
#  '후회': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9c90>,
#  '뻔하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9cd0>,
#  '따뜻하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9d10>,
#  '드라마': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9d50>,
#  '많다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9d90>,
#  '미도': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9dd0>,
#  '캐릭터': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9e10>,
#  '여러가지': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9e50>,
#  '결말': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9e90>,
#  '싫다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9ed0>,
#  'ㅠ': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9f10>,
#  '이제': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9f50>,
#  '알': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9f90>,
#  '잔잔하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddd9fd0>,
#  '재미': <gensim.models.keyedvectors.Vocab at 0x7f864dddd050>,
#  '중': <gensim.models.keyedvectors.Vocab at 0x7f864dddd090>,
#  '순위': <gensim.models.keyedvectors.Vocab at 0x7f864dddd0d0>,
#  '♥': <gensim.models.keyedvectors.Vocab at 0x7f864dddd110>,
#  '훌륭하다': <gensim.models.keyedvectors.Vocab at 0x7f864dddd150>,
#  '신동엽': <gensim.models.keyedvectors.Vocab at 0x7f864dddd190>,
#  'ㅋ': <gensim.models.keyedvectors.Vocab at 0x7f864dddd1d0>,
#  '순간': <gensim.models.keyedvectors.Vocab at 0x7f864dddd210>,
#  '캐치': <gensim.models.keyedvectors.Vocab at 0x7f864dddd250>,
#  '탁': <gensim.models.keyedvectors.Vocab at 0x7f864dddd290>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x7f864dddd2d0>,
#  '얄밉다': <gensim.models.keyedvectors.Vocab at 0x7f864dddd310>,
#  '웃기다': <gensim.models.keyedvectors.Vocab at 0x7f864dddd350>,
#  '미워하다': <gensim.models.keyedvectors.Vocab at 0x7f864dddd390>,
#  '감탄': <gensim.models.keyedvectors.Vocab at 0x7f864dddd3d0>,
#  '함': <gensim.models.keyedvectors.Vocab at 0x7f864dddd410>,
#  '대박': <gensim.models.keyedvectors.Vocab at 0x7f864dddd450>,
#  '일텐데': <gensim.models.keyedvectors.Vocab at 0x7f864dddd490>,
#  '왠': <gensim.models.keyedvectors.Vocab at 0x7f864dddd4d0>,
#  '이동욱': <gensim.models.keyedvectors.Vocab at 0x7f864dddd510>,
#  '인생': <gensim.models.keyedvectors.Vocab at 0x7f864dddd550>,
#  '전작': <gensim.models.keyedvectors.Vocab at 0x7f864dddd590>,
#  '비다': <gensim.models.keyedvectors.Vocab at 0x7f864dddd5d0>,
#  '떨어지다': <gensim.models.keyedvectors.Vocab at 0x7f864dddd610>,
#  '이지만': <gensim.models.keyedvectors.Vocab at 0x7f864dddd650>,
#  '쓰레기': <gensim.models.keyedvectors.Vocab at 0x7f864dddd690>,
#  '한국영': <gensim.models.keyedvectors.Vocab at 0x7f864dddd6d0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x7f864dddd710>,
#  '점': <gensim.models.keyedvectors.Vocab at 0x7f864dddd750>,
#  '대': <gensim.models.keyedvectors.Vocab at 0x7f864dddd790>,
#  '별로': <gensim.models.keyedvectors.Vocab at 0x7f864dddd7d0>,
#  '헐다': <gensim.models.keyedvectors.Vocab at 0x7f864dddd810>,
#  '니': <gensim.models.keyedvectors.Vocab at 0x7f864dddd850>,
#  '너무하다': <gensim.models.keyedvectors.Vocab at 0x7f864dddd890>,
#  '다소': <gensim.models.keyedvectors.Vocab at 0x7f864dddd8d0>,
#  '진부하다': <gensim.models.keyedvectors.Vocab at 0x7f864dddd910>,
#  '당시': <gensim.models.keyedvectors.Vocab at 0x7f864dddd950>,
#  '엔': <gensim.models.keyedvectors.Vocab at 0x7f864dddd990>,
#  '눈물': <gensim.models.keyedvectors.Vocab at 0x7f864dddd9d0>,
#  '흘리다': <gensim.models.keyedvectors.Vocab at 0x7f864dddda10>,
#  '신부': <gensim.models.keyedvectors.Vocab at 0x7f864dddda50>,
#  '로서': <gensim.models.keyedvectors.Vocab at 0x7f864dddda90>,
#  '사': <gensim.models.keyedvectors.Vocab at 0x7f864ddddad0>,
#  '명감': <gensim.models.keyedvectors.Vocab at 0x7f864ddddb10>,
#  '처절하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddddb50>,
#  '실천': <gensim.models.keyedvectors.Vocab at 0x7f864ddddb90>,
#  '제리': <gensim.models.keyedvectors.Vocab at 0x7f864ddddbd0>,
#  '자신': <gensim.models.keyedvectors.Vocab at 0x7f864ddddc10>,
#  '마저': <gensim.models.keyedvectors.Vocab at 0x7f864ddddc50>,
#  '부정': <gensim.models.keyedvectors.Vocab at 0x7f864ddddc90>,
#  '로키': <gensim.models.keyedvectors.Vocab at 0x7f864ddddcd0>,
#  '3.14': <gensim.models.keyedvectors.Vocab at 0x7f864ddddd10>,
#  '메이커': <gensim.models.keyedvectors.Vocab at 0x7f864ddddd50>,
#  '추석': <gensim.models.keyedvectors.Vocab at 0x7f864ddddd90>,
#  '특선영화': <gensim.models.keyedvectors.Vocab at 0x7f864dddddd0>,
#  '가족': <gensim.models.keyedvectors.Vocab at 0x7f864dddde10>,
#  '끼리': <gensim.models.keyedvectors.Vocab at 0x7f864dddde50>,
#  '보기': <gensim.models.keyedvectors.Vocab at 0x7f864dddde90>,
#  '우리': <gensim.models.keyedvectors.Vocab at 0x7f864dddded0>,
#  '애기': <gensim.models.keyedvectors.Vocab at 0x7f864ddddf10>,
#  '첫': <gensim.models.keyedvectors.Vocab at 0x7f864ddddf50>,
#  '자다': <gensim.models.keyedvectors.Vocab at 0x7f864ddddf90>,
#  '선택': <gensim.models.keyedvectors.Vocab at 0x7f864ddddfd0>,
#  '""': <gensim.models.keyedvectors.Vocab at 0x7f864dde0050>,
#  '굳다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0090>,
#  '괜찬': <gensim.models.keyedvectors.Vocab at 0x7f864dde00d0>,
#  '조합': <gensim.models.keyedvectors.Vocab at 0x7f864dde0110>,
#  '인거': <gensim.models.keyedvectors.Vocab at 0x7f864dde0150>,
#  '바로': <gensim.models.keyedvectors.Vocab at 0x7f864dde0190>,
#  '시': <gensim.models.keyedvectors.Vocab at 0x7f864dde01d0>,
#  '대의': <gensim.models.keyedvectors.Vocab at 0x7f864dde0210>,
#  '어머니': <gensim.models.keyedvectors.Vocab at 0x7f864dde0250>,
#  '나다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0290>,
#  '원작': <gensim.models.keyedvectors.Vocab at 0x7f864dde02d0>,
#  '드래곤볼': <gensim.models.keyedvectors.Vocab at 0x7f864dde0310>,
#  '에볼루션': <gensim.models.keyedvectors.Vocab at 0x7f864dde0350>,
#  '보다는': <gensim.models.keyedvectors.Vocab at 0x7f864dde0390>,
#  '만듬': <gensim.models.keyedvectors.Vocab at 0x7f864dde03d0>,
#  'ㅇㅇ': <gensim.models.keyedvectors.Vocab at 0x7f864dde0410>,
#  '예능': <gensim.models.keyedvectors.Vocab at 0x7f864dde0450>,
#  '방학': <gensim.models.keyedvectors.Vocab at 0x7f864dde0490>,
#  '아침': <gensim.models.keyedvectors.Vocab at 0x7f864dde04d0>,
#  '졸리다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0510>,
#  '눈': <gensim.models.keyedvectors.Vocab at 0x7f864dde0550>,
#  '비비다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0590>,
#  '우연히': <gensim.models.keyedvectors.Vocab at 0x7f864dde05d0>,
#  '채널': <gensim.models.keyedvectors.Vocab at 0x7f864dde0610>,
#  '돌리다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0650>,
#  '아프다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0690>,
#  '볼': <gensim.models.keyedvectors.Vocab at 0x7f864dde06d0>,
#  '권력': <gensim.models.keyedvectors.Vocab at 0x7f864dde0710>,
#  '에는': <gensim.models.keyedvectors.Vocab at 0x7f864dde0750>,
#  '의리': <gensim.models.keyedvectors.Vocab at 0x7f864dde0790>,
#  '역사': <gensim.models.keyedvectors.Vocab at 0x7f864dde07d0>,
#  '깨우치다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0810>,
#  '줌': <gensim.models.keyedvectors.Vocab at 0x7f864dde0850>,
#  '초롱': <gensim.models.keyedvectors.Vocab at 0x7f864dde0890>,
#  '팬심': <gensim.models.keyedvectors.Vocab at 0x7f864dde08d0>,
#  '내용': <gensim.models.keyedvectors.Vocab at 0x7f864dde0910>,
#  '배경음악': <gensim.models.keyedvectors.Vocab at 0x7f864dde0950>,
#  '달달': <gensim.models.keyedvectors.Vocab at 0x7f864dde0990>,
#  '행복하다': <gensim.models.keyedvectors.Vocab at 0x7f864dde09d0>,
#  '중간': <gensim.models.keyedvectors.Vocab at 0x7f864dde0a10>,
#  '본방': <gensim.models.keyedvectors.Vocab at 0x7f864dde0a50>,
#  '사수': <gensim.models.keyedvectors.Vocab at 0x7f864dde0a90>,
#  '스토리': <gensim.models.keyedvectors.Vocab at 0x7f864dde0ad0>,
#  '탄탄하다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0b10>,
#  '찾다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0b50>,
#  '나빠지다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0b90>,
#  '요새': <gensim.models.keyedvectors.Vocab at 0x7f864dde0bd0>,
#  '수백향': <gensim.models.keyedvectors.Vocab at 0x7f864dde0c10>,
#  '챙기다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0c50>,
#  '없어지다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0c90>,
#  '제목': <gensim.models.keyedvectors.Vocab at 0x7f864dde0cd0>,
#  '차다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0d10>,
#  '지다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0d50>,
#  '음': <gensim.models.keyedvectors.Vocab at 0x7f864dde0d90>,
#  '화질': <gensim.models.keyedvectors.Vocab at 0x7f864dde0dd0>,
#  '늘다': <gensim.models.keyedvectors.Vocab at 0x7f864dde0e10>,
#  '가을': <gensim.models.keyedvectors.Vocab at 0x7f864dde0e50>,
#  '이네': <gensim.models.keyedvectors.Vocab at 0x7f864dde0e90>,
#  'ost': <gensim.models.keyedvectors.Vocab at 0x7f864dde0ed0>,
#  '때문': <gensim.models.keyedvectors.Vocab at 0x7f864dde0f10>,
#  '이건': <gensim.models.keyedvectors.Vocab at 0x7f864dde0f50>,
#  '라는': <gensim.models.keyedvectors.Vocab at 0x7f864dde0f90>,
#  '밖에': <gensim.models.keyedvectors.Vocab at 0x7f864dde0fd0>,
#  '안': <gensim.models.keyedvectors.Vocab at 0x7f864dde5050>,
#  '벌써': <gensim.models.keyedvectors.Vocab at 0x7f864dde5090>,
#  '16년': <gensim.models.keyedvectors.Vocab at 0x7f864dde50d0>,
#  '전인데': <gensim.models.keyedvectors.Vocab at 0x7f864dde5110>,
#  '이런': <gensim.models.keyedvectors.Vocab at 0x7f864dde5150>,
#  '퀄리티': <gensim.models.keyedvectors.Vocab at 0x7f864dde5190>,
#  '대단하다': <gensim.models.keyedvectors.Vocab at 0x7f864dde51d0>,
#  '일단': <gensim.models.keyedvectors.Vocab at 0x7f864dde5210>,
#  '장국영': <gensim.models.keyedvectors.Vocab at 0x7f864dde5250>,
#  '자살': <gensim.models.keyedvectors.Vocab at 0x7f864dde5290>,
#  '안타깝다': <gensim.models.keyedvectors.Vocab at 0x7f864dde52d0>,
#  '이어서': <gensim.models.keyedvectors.Vocab at 0x7f864dde5310>,
#  '더': <gensim.models.keyedvectors.Vocab at 0x7f864dde5350>,
#  '극적': <gensim.models.keyedvectors.Vocab at 0x7f864dde5390>,
#  '뀰잼': <gensim.models.keyedvectors.Vocab at 0x7f864dde53d0>,
#  '이라': <gensim.models.keyedvectors.Vocab at 0x7f864dde5410>,
#  '구': <gensim.models.keyedvectors.Vocab at 0x7f864dde5450>,
#  '짱': <gensim.models.keyedvectors.Vocab at 0x7f864dde5490>,
#  '오': <gensim.models.keyedvectors.Vocab at 0x7f864dde54d0>,
#  '>': <gensim.models.keyedvectors.Vocab at 0x7f864dde5510>,
#  'ㅇ': <gensim.models.keyedvectors.Vocab at 0x7f864dde5550>,
#  '<': <gensim.models.keyedvectors.Vocab at 0x7f864dde5590>,
#  '예전': <gensim.models.keyedvectors.Vocab at 0x7f864dde55d0>,
#  '양심': <gensim.models.keyedvectors.Vocab at 0x7f864dde5610>,
#  '냉장고': <gensim.models.keyedvectors.Vocab at 0x7f864dde5650>,
#  '비슷하다': <gensim.models.keyedvectors.Vocab at 0x7f864dde5690>,
#  '움찔': <gensim.models.keyedvectors.Vocab at 0x7f864dde56d0>,
#  '한가지': <gensim.models.keyedvectors.Vocab at 0x7f864dde5710>,
#  '부탁': <gensim.models.keyedvectors.Vocab at 0x7f864dde5750>,
#  '드리다': <gensim.models.keyedvectors.Vocab at 0x7f864dde5790>,
#  '연기자': <gensim.models.keyedvectors.Vocab at 0x7f864dde57d0>,
#  '좀': <gensim.models.keyedvectors.Vocab at 0x7f864dde5810>,
#  '보호': <gensim.models.keyedvectors.Vocab at 0x7f864dde5850>,
#  '욕': <gensim.models.keyedvectors.Vocab at 0x7f864dde5890>,
#  '이나': <gensim.models.keyedvectors.Vocab at 0x7f864dde58d0>,
#  '폭력': <gensim.models.keyedvectors.Vocab at 0x7f864dde5910>,
#  '걱정': <gensim.models.keyedvectors.Vocab at 0x7f864dde5950>,
#  '성추행': <gensim.models.keyedvectors.Vocab at 0x7f864dde5990>,
#  '상가': <gensim.models.keyedvectors.Vocab at 0x7f864dde59d0>,
#  '모든': <gensim.models.keyedvectors.Vocab at 0x7f864dde5a10>,
#  '목격': <gensim.models.keyedvectors.Vocab at 0x7f864dde5a50>,
#  '저만': <gensim.models.keyedvectors.Vocab at 0x7f864dde5a90>,
#  '증언': <gensim.models.keyedvectors.Vocab at 0x7f864dde5ad0>,
#  '덕분': <gensim.models.keyedvectors.Vocab at 0x7f864dde5b10>,
#  '청소년': <gensim.models.keyedvectors.Vocab at 0x7f864dde5b50>,
#  '계속': <gensim.models.keyedvectors.Vocab at 0x7f864dde5b90>,
#  '경찰서': <gensim.models.keyedvectors.Vocab at 0x7f864dde5bd0>,
#  '야하다': <gensim.models.keyedvectors.Vocab at 0x7f864dde5c10>,
#  '섹시하다': <gensim.models.keyedvectors.Vocab at 0x7f864dde5c50>,
#  '어설프다': <gensim.models.keyedvectors.Vocab at 0x7f864dde5c90>,
#  '사다': <gensim.models.keyedvectors.Vocab at 0x7f864dde5cd0>,
#  '재밋었다': <gensim.models.keyedvectors.Vocab at 0x7f864dde5d10>,
#  'SF': <gensim.models.keyedvectors.Vocab at 0x7f864dde5d50>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x7f864dde5d90>,
#  '세기': <gensim.models.keyedvectors.Vocab at 0x7f864dde5dd0>,
#  '걸': <gensim.models.keyedvectors.Vocab at 0x7f864dde5e10>,
#  '95년': <gensim.models.keyedvectors.Vocab at 0x7f864dde5e50>,
#  '비디오': <gensim.models.keyedvectors.Vocab at 0x7f864dde5e90>,
#  '방': <gensim.models.keyedvectors.Vocab at 0x7f864dde5ed0>,
#  '빨리': <gensim.models.keyedvectors.Vocab at 0x7f864dde5f10>,
#  '!!!': <gensim.models.keyedvectors.Vocab at 0x7f864dde5f50>,
#  '허다': <gensim.models.keyedvectors.Vocab at 0x7f864dde5f90>,
#  '오래': <gensim.models.keyedvectors.Vocab at 0x7f864dde5fd0>,
#  '기다리다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8050>,
#  '틈': <gensim.models.keyedvectors.Vocab at 0x7f864dde8090>,
#  '감독': <gensim.models.keyedvectors.Vocab at 0x7f864dde80d0>,
#  '이름': <gensim.models.keyedvectors.Vocab at 0x7f864dde8110>,
#  '만으로도': <gensim.models.keyedvectors.Vocab at 0x7f864dde8150>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x7f864dde8190>,
#  '성룡': <gensim.models.keyedvectors.Vocab at 0x7f864dde81d0>,
#  '형님': <gensim.models.keyedvectors.Vocab at 0x7f864dde8210>,
#  '마이': <gensim.models.keyedvectors.Vocab at 0x7f864dde8250>,
#  '우상': <gensim.models.keyedvectors.Vocab at 0x7f864dde8290>,
#  '당신': <gensim.models.keyedvectors.Vocab at 0x7f864dde82d0>,
#  '장르': <gensim.models.keyedvectors.Vocab at 0x7f864dde8310>,
#  '이영화': <gensim.models.keyedvectors.Vocab at 0x7f864dde8350>,
#  '에도': <gensim.models.keyedvectors.Vocab at 0x7f864dde8390>,
#  '원': <gensim.models.keyedvectors.Vocab at 0x7f864dde83d0>,
#  '본': <gensim.models.keyedvectors.Vocab at 0x7f864dde8410>,
#  '매회': <gensim.models.keyedvectors.Vocab at 0x7f864dde8450>,
#  '리타': <gensim.models.keyedvectors.Vocab at 0x7f864dde8490>,
#  '자꾸': <gensim.models.keyedvectors.Vocab at 0x7f864dde84d0>,
#  '거슬리다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8510>,
#  '죄책감': <gensim.models.keyedvectors.Vocab at 0x7f864dde8550>,
#  '에나': <gensim.models.keyedvectors.Vocab at 0x7f864dde8590>,
#  '커서': <gensim.models.keyedvectors.Vocab at 0x7f864dde85d0>,
#  '만들다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8610>,
#  '웃음': <gensim.models.keyedvectors.Vocab at 0x7f864dde8650>,
#  '붙이다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8690>,
#  '정치': <gensim.models.keyedvectors.Vocab at 0x7f864dde86d0>,
#  '이랑': <gensim.models.keyedvectors.Vocab at 0x7f864dde8710>,
#  '묘사': <gensim.models.keyedvectors.Vocab at 0x7f864dde8750>,
#  '굉장하다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8790>,
#  '표현': <gensim.models.keyedvectors.Vocab at 0x7f864dde87d0>,
#  '흥행': <gensim.models.keyedvectors.Vocab at 0x7f864dde8810>,
#  '안나': <gensim.models.keyedvectors.Vocab at 0x7f864dde8850>,
#  '절대': <gensim.models.keyedvectors.Vocab at 0x7f864dde8890>,
#  '디테': <gensim.models.keyedvectors.Vocab at 0x7f864dde88d0>,
#  '일만': <gensim.models.keyedvectors.Vocab at 0x7f864dde8910>,
#  '따다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8950>,
#  '한마디': <gensim.models.keyedvectors.Vocab at 0x7f864dde8990>,
#  '달기': <gensim.models.keyedvectors.Vocab at 0x7f864dde89d0>,
#  '파고들다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8a10>,
#  '....': <gensim.models.keyedvectors.Vocab at 0x7f864dde8a50>,
#  '수록': <gensim.models.keyedvectors.Vocab at 0x7f864dde8a90>,
#  '빠져들다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8ad0>,
#  '13': <gensim.models.keyedvectors.Vocab at 0x7f864dde8b10>,
#  '살이': <gensim.models.keyedvectors.Vocab at 0x7f864dde8b50>,
#  '?...': <gensim.models.keyedvectors.Vocab at 0x7f864dde8b90>,
#  '성격': <gensim.models.keyedvectors.Vocab at 0x7f864dde8bd0>,
#  '만점': <gensim.models.keyedvectors.Vocab at 0x7f864dde8c10>,
#  '10000': <gensim.models.keyedvectors.Vocab at 0x7f864dde8c50>,
#  '재다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8c90>,
#  '다음': <gensim.models.keyedvectors.Vocab at 0x7f864dde8cd0>,
#  '핡': <gensim.models.keyedvectors.Vocab at 0x7f864dde8d10>,
#  '초반': <gensim.models.keyedvectors.Vocab at 0x7f864dde8d50>,
#  '황당하다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8d90>,
#  '설정': <gensim.models.keyedvectors.Vocab at 0x7f864dde8dd0>,
#  '힘들다': <gensim.models.keyedvectors.Vocab at 0x7f864dde8e10>,
#  '점차': <gensim.models.keyedvectors.Vocab at 0x7f864dde8e50>,
#  '판타지': <gensim.models.keyedvectors.Vocab at 0x7f864dde8e90>,
#  '근': <gensim.models.keyedvectors.Vocab at 0x7f864dde8ed0>,
#  '미래': <gensim.models.keyedvectors.Vocab at 0x7f864dde8f10>,
#  '현실': <gensim.models.keyedvectors.Vocab at 0x7f864dde8f50>,
#  '언론': <gensim.models.keyedvectors.Vocab at 0x7f864dde8f90>,
#  '탄압': <gensim.models.keyedvectors.Vocab at 0x7f864dde8fd0>,
#  '진지하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec050>,
#  '은유': <gensim.models.keyedvectors.Vocab at 0x7f864ddec090>,
#  '오카다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec0d0>,
#  '주다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec110>,
#  '예상': <gensim.models.keyedvectors.Vocab at 0x7f864ddec150>,
#  '훨씬': <gensim.models.keyedvectors.Vocab at 0x7f864ddec190>,
#  '별': <gensim.models.keyedvectors.Vocab at 0x7f864ddec1d0>,
#  '의외': <gensim.models.keyedvectors.Vocab at 0x7f864ddec210>,
#  '인도영화': <gensim.models.keyedvectors.Vocab at 0x7f864ddec250>,
#  '꽉차다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec290>,
#  '순수하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec2d0>,
#  '무엇': <gensim.models.keyedvectors.Vocab at 0x7f864ddec310>,
#  '인지': <gensim.models.keyedvectors.Vocab at 0x7f864ddec350>,
#  '다그': <gensim.models.keyedvectors.Vocab at 0x7f864ddec390>,
#  '웃': <gensim.models.keyedvectors.Vocab at 0x7f864ddec3d0>,
#  '대신': <gensim.models.keyedvectors.Vocab at 0x7f864ddec410>,
#  '한국': <gensim.models.keyedvectors.Vocab at 0x7f864ddec450>,
#  '국': <gensim.models.keyedvectors.Vocab at 0x7f864ddec490>,
#  '대로': <gensim.models.keyedvectors.Vocab at 0x7f864ddec4d0>,
#  'ㅎㅎㅎㅎㅎㅎㅎㅎ': <gensim.models.keyedvectors.Vocab at 0x7f864ddec510>,
#  '어찌': <gensim.models.keyedvectors.Vocab at 0x7f864ddec550>,
#  '가지다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec590>,
#  '인가': <gensim.models.keyedvectors.Vocab at 0x7f864ddec5d0>,
#  'ㅎㅎ': <gensim.models.keyedvectors.Vocab at 0x7f864ddec610>,
#  '메이': <gensim.models.keyedvectors.Vocab at 0x7f864ddec650>,
#  '최고봉': <gensim.models.keyedvectors.Vocab at 0x7f864ddec690>,
#  '초딩': <gensim.models.keyedvectors.Vocab at 0x7f864ddec6d0>,
#  '봣음': <gensim.models.keyedvectors.Vocab at 0x7f864ddec710>,
#  '비포미드나잇': <gensim.models.keyedvectors.Vocab at 0x7f864ddec750>,
#  '떠나다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec790>,
#  '보내다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec7d0>,
#  '심정': <gensim.models.keyedvectors.Vocab at 0x7f864ddec810>,
#  '또한': <gensim.models.keyedvectors.Vocab at 0x7f864ddec850>,
#  '아련하다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec890>,
#  '한편': <gensim.models.keyedvectors.Vocab at 0x7f864ddec8d0>,
#  '으로는': <gensim.models.keyedvectors.Vocab at 0x7f864ddec910>,
#  '지내다': <gensim.models.keyedvectors.Vocab at 0x7f864ddec950>,
#  '모습': <gensim.models.keyedvectors.Vocab at 0x7f864ddec990>,
#  '절로': <gensim.models.keyedvectors.Vocab at 0x7f864ddec9d0>,
#  '뭔가': <gensim.models.keyedvectors.Vocab at 0x7f864ddeca10>,
#  '코': <gensim.models.keyedvectors.Vocab at 0x7f864ddeca50>,
#  '스케': <gensim.models.keyedvectors.Vocab at 0x7f864ddeca90>,
#  '라디오': <gensim.models.keyedvectors.Vocab at 0x7f864ddecad0>,
#  '임진강': <gensim.models.keyedvectors.Vocab at 0x7f864ddecb10>,
#  '부르다': <gensim.models.keyedvectors.Vocab at 0x7f864ddecb50>,
#  '멈추다': <gensim.models.keyedvectors.Vocab at 0x7f864ddecb90>,
#  '않다': <gensim.models.keyedvectors.Vocab at 0x7f864ddecbd0>,
#  '한석규': <gensim.models.keyedvectors.Vocab at 0x7f864ddecc10>,
#  'ㅎㅎㅎ': <gensim.models.keyedvectors.Vocab at 0x7f864ddecc50>,
#  '~~~': <gensim.models.keyedvectors.Vocab at 0x7f864ddecc90>,
#  '쵝오': <gensim.models.keyedvectors.Vocab at 0x7f864ddeccd0>,
#  '허니': <gensim.models.keyedvectors.Vocab at 0x7f864ddecd10>,
#  '잼': <gensim.models.keyedvectors.Vocab at 0x7f864ddecd50>,
#  '꿀잼': <gensim.models.keyedvectors.Vocab at 0x7f864ddecd90>,
#  '개꿀잼': <gensim.models.keyedvectors.Vocab at 0x7f864ddecdd0>,
#  '한예슬': <gensim.models.keyedvectors.Vocab at 0x7f864ddece10>,
#  '이쁘다': <gensim.models.keyedvectors.Vocab at 0x7f864ddece50>,
#  '원래': <gensim.models.keyedvectors.Vocab at 0x7f864ddece90>,
#  '밉다': <gensim.models.keyedvectors.Vocab at 0x7f864ddeced0>,
#  '타다': <gensim.models.keyedvectors.Vocab at 0x7f864ddecf10>,
#  '터지다': <gensim.models.keyedvectors.Vocab at 0x7f864ddecf50>,
#  '옷': <gensim.models.keyedvectors.Vocab at 0x7f864ddecf90>,
#  '입다': <gensim.models.keyedvectors.Vocab at 0x7f864ddecfd0>,
#  '헤어': <gensim.models.keyedvectors.Vocab at 0x7f864dd70050>,
#  '메이크업': <gensim.models.keyedvectors.Vocab at 0x7f864dd70090>,
#  '괜찮다': <gensim.models.keyedvectors.Vocab at 0x7f864dd700d0>,
#  '딱': <gensim.models.keyedvectors.Vocab at 0x7f864dd70110>,
#  '.......': <gensim.models.keyedvectors.Vocab at 0x7f864dd70150>,
#  '반': <gensim.models.keyedvectors.Vocab at 0x7f864dd70190>,
#  '기대하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd701d0>,
#  '_': <gensim.models.keyedvectors.Vocab at 0x7f864dd70210>,
#  '훈남': <gensim.models.keyedvectors.Vocab at 0x7f864dd70250>,
#  '쉐프': <gensim.models.keyedvectors.Vocab at 0x7f864dd70290>,
#  '님': <gensim.models.keyedvectors.Vocab at 0x7f864dd702d0>,
#  '보구': <gensim.models.keyedvectors.Vocab at 0x7f864dd70310>,
#  '요리': <gensim.models.keyedvectors.Vocab at 0x7f864dd70350>,
#  '^': <gensim.models.keyedvectors.Vocab at 0x7f864dd70390>,
#  '시나리오': <gensim.models.keyedvectors.Vocab at 0x7f864dd703d0>,
#  '비고': <gensim.models.keyedvectors.Vocab at 0x7f864dd70410>,
#  '슨': <gensim.models.keyedvectors.Vocab at 0x7f864dd70450>,
#  '개인': <gensim.models.keyedvectors.Vocab at 0x7f864dd70490>,
#  '언제': <gensim.models.keyedvectors.Vocab at 0x7f864dd704d0>,
#  '팬텀': <gensim.models.keyedvectors.Vocab at 0x7f864dd70510>,
#  '크리스틴': <gensim.models.keyedvectors.Vocab at 0x7f864dd70550>,
#  '그런': <gensim.models.keyedvectors.Vocab at 0x7f864dd70590>,
#  '일이': <gensim.models.keyedvectors.Vocab at 0x7f864dd705d0>,
#  '전혀': <gensim.models.keyedvectors.Vocab at 0x7f864dd70610>,
#  'ㅠㅠㅠ': <gensim.models.keyedvectors.Vocab at 0x7f864dd70650>,
#  '처럼': <gensim.models.keyedvectors.Vocab at 0x7f864dd70690>,
#  '남편': <gensim.models.keyedvectors.Vocab at 0x7f864dd706d0>,
#  '곁': <gensim.models.keyedvectors.Vocab at 0x7f864dd70710>,
#  '돌아가다': <gensim.models.keyedvectors.Vocab at 0x7f864dd70750>,
#  '아쉬움': <gensim.models.keyedvectors.Vocab at 0x7f864dd70790>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x7f864dd707d0>,
#  '알파': <gensim.models.keyedvectors.Vocab at 0x7f864dd70810>,
#  '치노': <gensim.models.keyedvectors.Vocab at 0x7f864dd70850>,
#  '연': <gensim.models.keyedvectors.Vocab at 0x7f864dd70890>,
#  '기': <gensim.models.keyedvectors.Vocab at 0x7f864dd708d0>,
#  '명화': <gensim.models.keyedvectors.Vocab at 0x7f864dd70910>,
#  '태어나다': <gensim.models.keyedvectors.Vocab at 0x7f864dd70950>,
#  '뮤지컬': <gensim.models.keyedvectors.Vocab at 0x7f864dd70990>,
#  '역대': <gensim.models.keyedvectors.Vocab at 0x7f864dd709d0>,
#  '위': <gensim.models.keyedvectors.Vocab at 0x7f864dd70a10>,
#  '괜히': <gensim.models.keyedvectors.Vocab at 0x7f864dd70a50>,
#  '이지': <gensim.models.keyedvectors.Vocab at 0x7f864dd70a90>,
#  '대부': <gensim.models.keyedvectors.Vocab at 0x7f864dd70ad0>,
#  '바람': <gensim.models.keyedvectors.Vocab at 0x7f864dd70b10>,
#  '함께': <gensim.models.keyedvectors.Vocab at 0x7f864dd70b50>,
#  '레벨': <gensim.models.keyedvectors.Vocab at 0x7f864dd70b90>,
#  '명의': <gensim.models.keyedvectors.Vocab at 0x7f864dd70bd0>,
#  '계': <gensim.models.keyedvectors.Vocab at 0x7f864dd70c10>,
#  '마돈나': <gensim.models.keyedvectors.Vocab at 0x7f864dd70c50>,
#  '춤': <gensim.models.keyedvectors.Vocab at 0x7f864dd70c90>,
#  '노래실력': <gensim.models.keyedvectors.Vocab at 0x7f864dd70cd0>,
#  '보여주다': <gensim.models.keyedvectors.Vocab at 0x7f864dd70d10>,
#  '바비': <gensim.models.keyedvectors.Vocab at 0x7f864dd70d50>,
#  '바스코': <gensim.models.keyedvectors.Vocab at 0x7f864dd70d90>,
#  '이번': <gensim.models.keyedvectors.Vocab at 0x7f864dd70dd0>,
#  '결과': <gensim.models.keyedvectors.Vocab at 0x7f864dd70e10>,
#  '대해': <gensim.models.keyedvectors.Vocab at 0x7f864dd70e50>,
#  '서': <gensim.models.keyedvectors.Vocab at 0x7f864dd70e90>,
#  '불만': <gensim.models.keyedvectors.Vocab at 0x7f864dd70ed0>,
#  '품다': <gensim.models.keyedvectors.Vocab at 0x7f864dd70f10>,
#  '어쩌면': <gensim.models.keyedvectors.Vocab at 0x7f864dd70f50>,
#  '당연하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd70f90>,
#  '거지': <gensim.models.keyedvectors.Vocab at 0x7f864dd70fd0>,
#  '그래도': <gensim.models.keyedvectors.Vocab at 0x7f864dd74050>,
#  '어쩌': <gensim.models.keyedvectors.Vocab at 0x7f864dd74090>,
#  '깎다': <gensim.models.keyedvectors.Vocab at 0x7f864dd740d0>,
#  '내리다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74110>,
#  '깔다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74150>,
#  '충분하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74190>,
#  '이기다': <gensim.models.keyedvectors.Vocab at 0x7f864dd741d0>,
#  '자격': <gensim.models.keyedvectors.Vocab at 0x7f864dd74210>,
#  '코미디': <gensim.models.keyedvectors.Vocab at 0x7f864dd74250>,
#  '사극': <gensim.models.keyedvectors.Vocab at 0x7f864dd74290>,
#  '장혁': <gensim.models.keyedvectors.Vocab at 0x7f864dd742d0>,
#  '명품': <gensim.models.keyedvectors.Vocab at 0x7f864dd74310>,
#  '땐': <gensim.models.keyedvectors.Vocab at 0x7f864dd74350>,
#  '온': <gensim.models.keyedvectors.Vocab at 0x7f864dd74390>,
#  '이서': <gensim.models.keyedvectors.Vocab at 0x7f864dd743d0>,
#  '마련': <gensim.models.keyedvectors.Vocab at 0x7f864dd74410>,
#  '사마': <gensim.models.keyedvectors.Vocab at 0x7f864dd74450>,
#  '치고': <gensim.models.keyedvectors.Vocab at 0x7f864dd74490>,
#  '그날': <gensim.models.keyedvectors.Vocab at 0x7f864dd744d0>,
#  '저녁': <gensim.models.keyedvectors.Vocab at 0x7f864dd74510>,
#  '기분': <gensim.models.keyedvectors.Vocab at 0x7f864dd74550>,
#  '탓': <gensim.models.keyedvectors.Vocab at 0x7f864dd74590>,
#  '진': <gensim.models.keyedvectors.Vocab at 0x7f864dd745d0>,
#  '그렇게': <gensim.models.keyedvectors.Vocab at 0x7f864dd74610>,
#  '옛날': <gensim.models.keyedvectors.Vocab at 0x7f864dd74650>,
#  '워낭소리': <gensim.models.keyedvectors.Vocab at 0x7f864dd74690>,
#  '울다': <gensim.models.keyedvectors.Vocab at 0x7f864dd746d0>,
#  '더빙': <gensim.models.keyedvectors.Vocab at 0x7f864dd74710>,
#  '자막': <gensim.models.keyedvectors.Vocab at 0x7f864dd74750>,
#  '데': <gensim.models.keyedvectors.Vocab at 0x7f864dd74790>,
#  '5년': <gensim.models.keyedvectors.Vocab at 0x7f864dd747d0>,
#  '뒤': <gensim.models.keyedvectors.Vocab at 0x7f864dd74810>,
#  '찾아보다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74850>,
#  '포': <gensim.models.keyedvectors.Vocab at 0x7f864dd74890>,
#  '씨': <gensim.models.keyedvectors.Vocab at 0x7f864dd748d0>,
#  '연말': <gensim.models.keyedvectors.Vocab at 0x7f864dd74910>,
#  '추천': <gensim.models.keyedvectors.Vocab at 0x7f864dd74950>,
#  '사회': <gensim.models.keyedvectors.Vocab at 0x7f864dd74990>,
#  '치부': <gensim.models.keyedvectors.Vocab at 0x7f864dd749d0>,
#  '정확하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74a10>,
#  '예언': <gensim.models.keyedvectors.Vocab at 0x7f864dd74a50>,
#  '찌다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74a90>,
#  '짜다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74ad0>,
#  ':)': <gensim.models.keyedvectors.Vocab at 0x7f864dd74b10>,
#  '엣날': <gensim.models.keyedvectors.Vocab at 0x7f864dd74b50>,
#  '제일': <gensim.models.keyedvectors.Vocab at 0x7f864dd74b90>,
#  '슈퍼': <gensim.models.keyedvectors.Vocab at 0x7f864dd74bd0>,
#  '초': <gensim.models.keyedvectors.Vocab at 0x7f864dd74c10>,
#  '입': <gensim.models.keyedvectors.Vocab at 0x7f864dd74c50>,
#  '벌리다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74c90>,
#  '중동': <gensim.models.keyedvectors.Vocab at 0x7f864dd74cd0>,
#  '새롭다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74d10>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x7f864dd74d50>,
#  '명': <gensim.models.keyedvectors.Vocab at 0x7f864dd74d90>,
#  '참여': <gensim.models.keyedvectors.Vocab at 0x7f864dd74dd0>,
#  '길': <gensim.models.keyedvectors.Vocab at 0x7f864dd74e10>,
#  '래': <gensim.models.keyedvectors.Vocab at 0x7f864dd74e50>,
#  '얼마나': <gensim.models.keyedvectors.Vocab at 0x7f864dd74e90>,
#  '바뀌다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74ed0>,
#  '궁금하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74f10>,
#  '올리다': <gensim.models.keyedvectors.Vocab at 0x7f864dd74f50>,
#  '아버지': <gensim.models.keyedvectors.Vocab at 0x7f864dd74f90>,
#  '이자': <gensim.models.keyedvectors.Vocab at 0x7f864dd74fd0>,
#  '무사': <gensim.models.keyedvectors.Vocab at 0x7f864dd76050>,
#  '일생': <gensim.models.keyedvectors.Vocab at 0x7f864dd76090>,
#  '의미': <gensim.models.keyedvectors.Vocab at 0x7f864dd760d0>,
#  '죽음': <gensim.models.keyedvectors.Vocab at 0x7f864dd76110>,
#  '일지': <gensim.models.keyedvectors.Vocab at 0x7f864dd76150>,
#  '신념': <gensim.models.keyedvectors.Vocab at 0x7f864dd76190>,
#  '멋': <gensim.models.keyedvectors.Vocab at 0x7f864dd761d0>,
#  '진일': <gensim.models.keyedvectors.Vocab at 0x7f864dd76210>,
#  '물결': <gensim.models.keyedvectors.Vocab at 0x7f864dd76250>,
#  '다만': <gensim.models.keyedvectors.Vocab at 0x7f864dd76290>,
#  '엔딩': <gensim.models.keyedvectors.Vocab at 0x7f864dd762d0>,
#  '배심원': <gensim.models.keyedvectors.Vocab at 0x7f864dd76310>,
#  '상대로': <gensim.models.keyedvectors.Vocab at 0x7f864dd76350>,
#  '늘어놓다': <gensim.models.keyedvectors.Vocab at 0x7f864dd76390>,
#  '연설': <gensim.models.keyedvectors.Vocab at 0x7f864dd763d0>,
#  '작위': <gensim.models.keyedvectors.Vocab at 0x7f864dd76410>,
#  '이고': <gensim.models.keyedvectors.Vocab at 0x7f864dd76450>,
#  '신파': <gensim.models.keyedvectors.Vocab at 0x7f864dd76490>,
#  '흔들리다': <gensim.models.keyedvectors.Vocab at 0x7f864dd764d0>,
#  '무죄': <gensim.models.keyedvectors.Vocab at 0x7f864dd76510>,
#  '돌아서다': <gensim.models.keyedvectors.Vocab at 0x7f864dd76550>,
#  '억지스럽다': <gensim.models.keyedvectors.Vocab at 0x7f864dd76590>,
#  'ㅜㅠ': <gensim.models.keyedvectors.Vocab at 0x7f864dd765d0>,
#  '애정': <gensim.models.keyedvectors.Vocab at 0x7f864dd76610>,
#  '둘': <gensim.models.keyedvectors.Vocab at 0x7f864dd76650>,
#  '멜로': <gensim.models.keyedvectors.Vocab at 0x7f864dd76690>,
#  '보다도': <gensim.models.keyedvectors.Vocab at 0x7f864dd766d0>,
#  '최영장군': <gensim.models.keyedvectors.Vocab at 0x7f864dd76710>,
#  '이민호': <gensim.models.keyedvectors.Vocab at 0x7f864dd76750>,
#  '방향': <gensim.models.keyedvectors.Vocab at 0x7f864dd76790>,
#  '묻다': <gensim.models.keyedvectors.Vocab at 0x7f864dd767d0>,
#  '노래': <gensim.models.keyedvectors.Vocab at 0x7f864dd76810>,
#  '생각나다': <gensim.models.keyedvectors.Vocab at 0x7f864dd76850>,
#  '단순하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd76890>,
#  '엿보다': <gensim.models.keyedvectors.Vocab at 0x7f864dd768d0>,
#  '걸작': <gensim.models.keyedvectors.Vocab at 0x7f864dd76910>,
#  '안보': <gensim.models.keyedvectors.Vocab at 0x7f864dd76950>,
#  '고도': <gensim.models.keyedvectors.Vocab at 0x7f864dd76990>,
#  '오스트레일리아': <gensim.models.keyedvectors.Vocab at 0x7f864dd769d0>,
#  '조금': <gensim.models.keyedvectors.Vocab at 0x7f864dd76a10>,
#  '프랑스': <gensim.models.keyedvectors.Vocab at 0x7f864dd76a50>,
#  '떠돌다': <gensim.models.keyedvectors.Vocab at 0x7f864dd76a90>,
#  '신': <gensim.models.keyedvectors.Vocab at 0x7f864dd76ad0>,
#  '심장': <gensim.models.keyedvectors.Vocab at 0x7f864dd76b10>,
#  '쫄깃하': <gensim.models.keyedvectors.Vocab at 0x7f864dd76b50>,
#  '준': <gensim.models.keyedvectors.Vocab at 0x7f864dd76b90>,
#  '웰': <gensim.models.keyedvectors.Vocab at 0x7f864dd76bd0>,
#  '메이드': <gensim.models.keyedvectors.Vocab at 0x7f864dd76c10>,
#  '범죄물': <gensim.models.keyedvectors.Vocab at 0x7f864dd76c50>,
#  '류승범': <gensim.models.keyedvectors.Vocab at 0x7f864dd76c90>,
#  '황정민': <gensim.models.keyedvectors.Vocab at 0x7f864dd76cd0>,
#  '즐겁다': <gensim.models.keyedvectors.Vocab at 0x7f864dd76d10>,
#  '만들어지다': <gensim.models.keyedvectors.Vocab at 0x7f864dd76d50>,
#  '기쁨': <gensim.models.keyedvectors.Vocab at 0x7f864dd76d90>,
#  '배': <gensim.models.keyedvectors.Vocab at 0x7f864dd76dd0>,
#  '등장인물': <gensim.models.keyedvectors.Vocab at 0x7f864dd76e10>,
#  '깔끔하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd76e50>,
#  '절제': <gensim.models.keyedvectors.Vocab at 0x7f864dd76e90>,
#  '소설가': <gensim.models.keyedvectors.Vocab at 0x7f864dd76ed0>,
#  '답': <gensim.models.keyedvectors.Vocab at 0x7f864dd76f10>,
#  '무척': <gensim.models.keyedvectors.Vocab at 0x7f864dd76f50>,
#  '엄마': <gensim.models.keyedvectors.Vocab at 0x7f864dd76f90>,
#  '운전': <gensim.models.keyedvectors.Vocab at 0x7f864dd76fd0>,
#  '아이맥스': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a050>,
#  'D': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a090>,
#  '개봉': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a0d0>,
#  '아쉽다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a110>,
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a150>,
#  '거임': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a190>,
#  '완죤': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a1d0>,
#  '스타': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a210>,
#  '무능하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a250>,
#  '정부': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a290>,
#  '국민': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a2d0>,
#  '의지': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a310>,
#  '참신하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a350>,
#  '몇': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a390>,
#  '야': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a3d0>,
#  '우와': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a410>,
#  '호킹': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a450>,
#  'ㅋㅋㅋㅋㅋㅋㅋ': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a490>,
#  '누': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a4d0>,
#  '라서': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a510>,
#  '보통': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a550>,
#  '전쟁영화': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a590>,
#  '특유': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a5d0>,
#  '연출': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a610>,
#  '력': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a650>,
#  '돋보이다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a690>,
#  '이정현': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a6d0>,
#  '독특하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a710>,
#  '전형': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a750>,
#  '사이코': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a790>,
#  '갠': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a7d0>,
#  '"': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a810>,
#  '우릴': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a850>,
#  '손': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a890>,
#  '욕망': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a8d0>,
#  '이야': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a910>,
#  '."': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a950>,
#  '명대사': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a990>,
#  '편': <gensim.models.keyedvectors.Vocab at 0x7f864dd7a9d0>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x7f864dd7aa10>,
#  '~~~~': <gensim.models.keyedvectors.Vocab at 0x7f864dd7aa50>,
#  '된거': <gensim.models.keyedvectors.Vocab at 0x7f864dd7aa90>,
#  '점도': <gensim.models.keyedvectors.Vocab at 0x7f864dd7aad0>,
#  '아깝다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ab10>,
#  '버금': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ab50>,
#  '임': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ab90>,
#  '결코': <gensim.models.keyedvectors.Vocab at 0x7f864dd7abd0>,
#  '떠오르다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ac10>,
#  '특별하다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ac50>,
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ac90>,
#  '정일우': <gensim.models.keyedvectors.Vocab at 0x7f864dd7acd0>,
#  '상투': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ad10>,
#  '기다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ad50>,
#  '필요없다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ad90>,
#  '존경': <gensim.models.keyedvectors.Vocab at 0x7f864dd7add0>,
#  '반지': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ae10>,
#  '제왕': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ae50>,
#  '피터': <gensim.models.keyedvectors.Vocab at 0x7f864dd7ae90>,
#  '잭슨': <gensim.models.keyedvectors.Vocab at 0x7f864dd7aed0>,
#  '찍다': <gensim.models.keyedvectors.Vocab at 0x7f864dd7af10>,
#  '부터가': <gensim.models.keyedvectors.Vocab at 0x7f864dd7af50>,
#  '씩': <gensim.models.keyedvectors.Vocab at 0x7f864dd7af90>,
#  '물론': <gensim.models.keyedvectors.Vocab at 0x7f864dd7afd0>,
#  '감독판': <gensim.models.keyedvectors.Vocab at 0x7f864dd7e050>,
#  '쩌': <gensim.models.keyedvectors.Vocab at 0x7f864dd7e090>,
#  'ㄷㄷㄷ': <gensim.models.keyedvectors.Vocab at 0x7f864dd7e0d0>,
#  '캬': <gensim.models.keyedvectors.Vocab at 0x7f864dd7e110>,
#  '추억': <gensim.models.keyedvectors.Vocab at 0x7f864dd7e150>,
#  '녹화': <gensim.models.keyedvectors.Vocab at 0x7f864dd7e190>,
#  '번': <gensim.models.keyedvectors.Vocab at 0x7f864dd7e1d0>,
#  'ㅜㅜ': <gensim.models.keyedvectors.Vocab at 0x7f864dd7e210>,
#  ...}

# %%
model.wv.most_similar("설경구")
# Out:
# INFO:gensim.models.keyedvectors:precomputing L2-norms of word weight vectors
# [('문소리', 0.6496538519859314),
#  ('로빈윌리엄스', 0.6354153156280518),
#  ('문정희', 0.6305896043777466),
#  ('안성기', 0.6219744682312012),
#  ('패닝', 0.6166368722915649),
#  ('송윤아', 0.6034888625144958),
#  ('주지훈', 0.6031726598739624),
#  ('서영희', 0.5982471704483032),
#  ('천우희', 0.5973948240280151),
#  ('추상미', 0.5968494415283203)]

# %%
# 한석규는 어떤 배우인가? 
# 원하는 단어가 어휘에 포함되었는지를 확인하고 싶을 땐, model.wv.vocab을 접근하면 됩니다.
if "한석규" in model.wv.vocab: 
  for word, score in model.wv.most_similar("한석규"):
    print(word, score)
else:
  raise ValueError("out of vocab")
# Out:
# 윤제문 0.6487352848052979
# 오달수 0.63154536485672
# 송강호 0.6285011172294617
# 임시완 0.6165424585342407
# 정려원 0.6142942905426025
# 차승원 0.6134588718414307
# 이제훈 0.6108124852180481
# 심혜진 0.6050857305526733
# 정보석 0.6043567657470703
# 황정민 0.6013203263282776

# %%
# 어간 추출을 진행했기 때문에, "재밌어"라는 단어도 "재밌다"로 정규화되었을 것입니다.
if "재밌다" in model.wv.vocab:
  for word, score in model.wv.most_similar("재밌다"):
    print(word, score)
else:
  raise ValueError("out of vocab")
# Out:
# 재미있다 0.9388811588287354
# 재다 0.843007504940033
# 재밋 0.6832064986228943
# 쟈밋 0.6739248037338257
# 재밋는듯 0.6704350113868713
# 재밋었습니 0.6672142148017883
# 잼남 0.6625919342041016
# 재밋어용 0.6621266007423401
# 토탈리콜 0.6534591317176819
# 재밋어 0.6479905843734741

# %% [markdown]
# ## 질문거리 (reverse-engineering)
#
# 인물 명사 와 형용사는 왜 유사도 에서 나오지 않는가
# 인물은 같은 윈도우에서  님 ,연기 인물을 꾸며주는 말이 나오고 다른 인물 명사에서도

# %%
if "인도영화" in model.wv.vocab:
  for word, score in model.wv.most_similar("인도영화"):
    print(word, score)
else:
  raise ValueError("out of vocab")
# Out:
# 뮤지컬영화 0.6471281051635742
# 영화 0.6291313171386719
# 굉장 0.6074318885803223
# 블랙홀 0.6020694971084595
# 애니메이션영화 0.5967851877212524
# 뿐더러 0.5894656777381897
# 특색 0.5843429565429688
# 까다롭다 0.5787320137023926
# 벅스라이프 0.5784770846366882
# 아노하나 0.5782922506332397
