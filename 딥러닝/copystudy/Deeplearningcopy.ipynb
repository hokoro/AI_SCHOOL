# %% [markdown]
# ##MSE : 평균 제곱 오차 직접 만들기

# %%
import numpy as np 
'''
medal_predict = [15,12,18]
medal = [21,10,14]

medal_min = [a-b for a,b in zip(medal,medal_predict)]
medal_squre = [x**2 for x in medal_min]
medal_sum = sum(medal_squre)
medal_mean = medal_sum / len(medal)
print(medal_mean)
'''

medal_predict = np.array([15,12,18],dtype = np.int32)
medal = np.array([21,10,14])
medal_sub = medal - medal_predict #np.substract(medal,medal_predict)
medal_square = np.square(medal_sub)
print(medal_sqrt)
#medal_sum = np.sum(medal_square)
np.mean(medal_square) #바로 np.mean 로 구현 가능
# Out:
# [36  4 16]
# 18.666666666666668

# %% [markdown]
# #신경망을 만들떄 일련의 순서
#
# ##1. 데이터를 불러온다
# ##2. 신경망 모델을 만든다.
# ##3. 최적화를 어떻게 할것인지
# ##4. 학습

# %%
#Xor 다층 퍼셉트론 으로 풀기

#1단계 데이터를 불러온다 (만든다)
import tensorflow as tf 
import numpy as np 

x = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

# %%
#2단계 모델을 만든다

model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(units = 2,activation='elu',input_shape =(2,)),
        tf.keras.layers.Dense(units = 5,activation='elu'),
        tf.keras.layers.Dense(units = 7,activation='elu'),
        tf.keras.layers.Dense(units = 1,activation='sigmoid')
       
])

# %%
#3단계 최적화 문제 
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001),
              loss ='mse' )

# %%
#학습 
model.fit(x,y,epochs = 1000) #학습 데이터
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.0869e-04
# Epoch 2/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0730e-04
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.0593e-04
# Epoch 4/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0455e-04
# Epoch 5/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.0319e-04
# Epoch 6/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0183e-04
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0047e-04
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9912e-04
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9778e-04
# Epoch 10/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.9644e-04
# Epoch 11/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9510e-04
# Epoch 12/1000
# ...

# %%
print(model.predict(x))
# Out:
# [[0.00706556]
#  [0.9883551 ]
#  [0.99394333]
#  [0.0110105 ]]
