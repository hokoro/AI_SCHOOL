# %% [markdown]
# ##나이브 베이즈 분류기 구현

# %% [markdown]
# <br>
# 1. 베이즈 정리. <br>
#
#  $P(A| W_1, W_2, W_3,...) = {P(W_1, W_2, W_3,...|A) \cdot P(A) \over P(W_1, W_2, W_3,....)}$ <br>
#  $P(B| W_1, W_2, W_3,...) = {P(W_1, W_2, W_3,...|B) \cdot P(B) \over P(W_1, W_2, W_3,....)}$
#
# <br>
# 2. 동일한 분모를 무시하면 다음 비례관계가 성립된다. <br>
#
#  $P(A| W_1, W_2, W_3, \ldots) \sim P(W_1, W_2, W_3,...|A) \cdot P(A) $ <br>
#  $P(B| W_1, W_2, W_3, \ldots) \sim P(W_1, W_2, W_3,...|B) \cdot P(B) $
#
# <br>
# 3. 독립적인 단어 분포를 전제하면 다음과 같이 분해할 수 있다. <br>
#
#  $P(A| W_1, W_2, W_3, \ldots) \sim  P(W_1|A)\cdot P(W_2|A)\cdot P(W_3|A) \cdots P(A) $ <br>
#  $P(B| W_1, W_2, W_3, \ldots) \sim P(W_1|B)\cdot P(W_2|B)\cdot P(W_3|B) \cdots P(B) $
#
# <br>
# 4. 이제는 로그함수를 적용해 본다. <br>
#
# $Log_A \sim  Log(P(W_1|A)) +  Log(P(W_2|A)) + Log(P(W_3|A)) + \ldots + Log(P(A)) $ <br>
# $Log_B \sim  Log(P(W_1|B)) +  Log(P(W_2|B)) + Log(P(W_3|B)) + \ldots + Log(P(B)) $
# <br>
#
# **<span style="color:blue">결론</span>**:  $Log_A$와 $Log_B$를 비교해서 큰 쪽으로 인식!

# %%
import pandas as pd
import numpy as np
import re

# %%
# A 유형의 트윗을 읽어온다. 
f = open("/content/drive/MyDrive/인공지능사관학교/빅데이터/03_확률 모델링_업데이트/data/tweets_A.txt","r",encoding="ms949")    # Encoding 주의!
ta = f.readlines()
f.close()

# B 유형의 트윗을 읽어온다. 
f = open("/content/drive/MyDrive/인공지능사관학교/빅데이터/03_확률 모델링_업데이트/data/tweets_B.txt","r", encoding="ms949")   # Encoding 주의!
tb = f.readlines()
f.close()

# %%
print(len(ta))
print(len(tb))
# Out:
# 150
# 150

# %% [markdown]
# ##데이터 전처리

# %%
def preprocessor(tweet):
  freq_dict = {}
  for a_line in tweet:
        a_line = a_line.lower()               # 소문자화.
        a_line = re.sub(r"\W"," ",a_line)     # 특수문자 제거.
        a_line = re.sub(r"\d", " ", a_line)   # 숫자 제거.
        a_line = re.sub("a|the|and|or|because|at", " ",a_line)  #  불용어 제거.
        a_line = a_line.split()  
        for a_word in a_line:
          if len(a_word) > 3:
            if a_word in freq_dict:
              freq_dict[a_word]+=1
            else:
              freq_dict[a_word] = 2 #처음 있지만 이 단어가 없다고 해서 도수를 0 으로 세팅하면 확률이 0 이된다  = log 0 은 -inf 에러가 발생할수 있음
  return freq_dict

# %% [markdown]
# ##학습 모형 준비

# %%
# Series로 변환.
freq_a = pd.Series(preprocessor(ta)).sort_values(ascending=False)
freq_b = pd.Series(preprocessor(tb)).sort_values(ascending=False)

# %%
n_voca = 300
freq_a = freq_a.iloc[:n_voca]
freq_b = freq_b.iloc[:n_voca]

# %%
freq_a_sum = freq_a.sum()
log_prob_a = dict(np.log(freq_a/freq_a.sum()))
log_prob_a
# Out:
# {'been': -5.927592470513571,
#  'best': -6.215274542965353,
#  'bhijeetmk': -6.620739651073516,
#  'bien': -6.215274542965353,
#  'biggoldring': -6.620739651073516,
#  'bility': -6.620739651073516,
#  'blocked': -6.620739651073516,
#  'blog': -5.011301738639416,
#  'blueh': -6.620739651073516,
#  'both': -6.620739651073516,
#  'bounce': -5.367976682578148,
#  'bout': -5.011301738639416,
#  'bugs': -6.620739651073516,
#  'bulk': -6.620739651073516,
#  'bywbf': -6.215274542965353,
#  'ccion': -6.620739651073516,
#  'ccount': -5.116662254297243,
#  'cemsism': -6.620739651073516,
#  'ceofsp': -6.620739651073516,
#  'check': -6.215274542965353,
#  'checked': -6.620739651073516,
#  'cher': -5.927592470513571,
#  'chez': -6.620739651073516,
#  'chrislem': -5.522127362405407,
#  'client': -5.704448919199361,
#  'clients': -6.620739651073516,
#  'comp': -6.215274542965353,
#  'confusing': -6.620739651073516,
#  'consider': -6.620739651073516,
#  'cont': -6.620739651073516,
#  'ctcode': -6.620739651073516,
#  'ction': -4.674829502018204,
#  'currently': -6.215274542965353,
#  'customize': -6.620739651073516,
#  'customized': -6.620739651073516,
#  'ddition': -5.927592470513571,
#  'ddresses': -6.620739651073516,
#  'debug': -6.620739651073516,
#  'decre': -6.620739651073516,
#  'delisted': -6.620739651073516,
#  'delivering': -6.620739651073516,
#  'ders': -6.620739651073516,
#  'design': -4.915991558835091,
#  'designed': -6.620739651073516,
#  'devongovett': -5.927592470513571,
#  'dist': -6.620739651073516,
#  'dlouni': -5.927592470513571,
#  'dmon': -6.620739651073516,
#  'docs': -6.620739651073516,
#  'documenting': -6.620739651073516,
#  'does': -6.215274542965353,
#  'dpress': -5.116662254297243,
#  'drienneleigh': -6.620739651073516,
#  'drop': -6.620739651073516,
#  'drup': -5.234445289953626,
#  'dumped': -6.620739651073516,
#  'dzuelke': -6.215274542965353,
#  'ecommerce': -5.927592470513571,
#  'edocr': -5.927592470513571,
#  'eebz': -6.620739651073516,
#  'eecms': -6.215274542965353,
#  'eepurl': -6.215274542965353,
#  'elie__': -6.215274542965353,
#  'elmi': -6.620739651073516,
#  'enginehosting': -6.620739651073516,
#  'enquiring': -6.620739651073516,
#  'entries': -5.927592470513571,
#  'ericc': -6.620739651073516,
#  'eshuys': -5.011301738639416,
#  'even': -6.620739651073516,
#  'every': -6.620739651073516,
#  'exemple': -6.620739651073516,
#  'find': -6.215274542965353,
#  'flo_ri': -6.620739651073516,
#  'fois': -6.620739651073516,
#  'free': -6.215274542965353,
#  'freel': -5.116662254297243,
#  'frid': -6.215274542965353,
#  'from': -5.116662254297243,
#  'fter': -6.215274542965353,
#  'fwiw': -6.620739651073516,
#  'gement': -6.215274542965353,
#  'gener': -6.215274542965353,
#  'gerer': -6.620739651073516,
#  'gets': -6.620739651073516,
#  'getting': -6.620739651073516,
#  'gidogeek': -6.620739651073516,
#  'github': -6.215274542965353,
#  'give': -5.927592470513571,
#  'goes': -6.620739651073516,
#  'good': -5.927592470513571,
#  'grid': -5.927592470513571,
#  'guill': -6.620739651073516,
#  'help': -3.879899627148316,
#  'henrik': -6.620739651073516,
#  'here': -5.704448919199361,
#  'highly': -6.620739651073516,
#  'hmdzz': -6.620739651073516,
#  'homem': -4.674829502018204,
#  'homep': -6.620739651073516,
#  'hotm': -6.620739651073516,
#  'html': -5.927592470513571,
#  'http': -2.6134064658410456,
#  'https': -5.116662254297243,
#  'hyperion': -2.154831532418933,
#  'icntmx': -6.620739651073516,
#  'idem': -6.620739651073516,
#  'ightened': -6.620739651073516,
#  'ilchimp': -4.605836630531252,
#  'iler': -6.215274542965353,
#  'iljet': -6.215274542965353,
#  'implement': -5.011301738639416,
#  'improve': -6.620739651073516,
#  'inbound': -6.215274542965353,
#  'incre': -6.215274542965353,
#  'info': -6.215274542965353,
#  'inline': -6.620739651073516,
#  'inst': -6.215274542965353,
#  'integr': -4.423515073737297,
#  'interspire': -5.522127362405407,
#  'investig': -6.620739651073516,
#  'ison': -6.620739651073516,
#  'issues': -5.116662254297243,
#  'jeremyweir': -6.620739651073516,
#  'jobs': -5.522127362405407,
#  'josscrowcroft': -6.620739651073516,
#  'jquery': -6.215274542965353,
#  'jsfiddle': -5.704448919199361,
#  'just': -4.828980181845462,
#  'kennydude': -6.620739651073516,
#  'kennyfr': -6.620739651073516,
#  'kflow': -6.620739651073516,
#  'khiger': -6.620739651073516,
#  'king': -6.215274542965353,
#  'know': -6.215274542965353,
#  'lbertson': -6.620739651073516,
#  'libr': -5.927592470513571,
#  'like': -5.522127362405407,
#  'line': -6.215274542965353,
#  'link': -6.620739651073516,
#  'linux': -5.927592470513571,
#  'liser': -6.620739651073516,
#  'list': -6.215274542965353,
#  'listes': -6.620739651073516,
#  'lite': -6.620739651073516,
#  'live': -6.215274542965353,
#  'ller': -6.620739651073516,
#  'login': -6.215274542965353,
#  'logo': -6.215274542965353,
#  'longreply': -5.522127362405407,
#  'look': -5.367976682578148,
#  'looked': -6.620739651073516,
#  'looking': -5.116662254297243,
#  'looks': -6.620739651073516,
#  'love': -6.215274542965353,
#  'ltern': -6.215274542965353,
#  'meeiw': -6.620739651073516,
#  'mess': -5.927592470513571,
#  'method': -6.620739651073516,
#  'mich': -6.620739651073516,
#  'million': -6.215274542965353,
#  'mind': -4.828980181845462,
#  'module': -6.620739651073516,
#  'modules': -5.704448919199361,
#  'moins': -6.620739651073516,
#  'mois': -6.620739651073516,
#  'mples': -6.620739651073516,
#  'myvuh': -6.620739651073516,
#  'nbowser': -6.620739651073516,
#  'ndino': -6.620739651073516,
#  'need': -5.927592470513571,
#  'needed': -5.927592470513571,
#  'newsletters': -4.828980181845462,
#  'nice': -6.215274542965353,
#  'nkeshk': -6.620739651073516,
#  'nkioh': -6.620739651073516,
#  'nnib': -6.215274542965353,
#  'nnot': -6.620739651073516,
#  'nojr': -6.620739651073516,
#  'nonbulle': -6.620739651073516,
#  'notes': -6.215274542965353,
#  'notific': -6.215274542965353,
#  'nsmith': -6.215274542965353,
#  'nullm': -6.215274542965353,
#  'nyone': -5.927592470513571,
#  'occur': -6.620739651073516,
#  'offer': -6.620739651073516,
#  'offici': -6.215274542965353,
#  'only': -6.620739651073516,
#  'option': -6.620739651073516,
#  'outboud': -6.215274542965353,
#  'over': -5.927592470513571,
#  'permettent': -6.620739651073516,
#  'photo': -6.620739651073516,
#  'plone': -6.215274542965353,
#  'plus': -6.620739651073516,
#  'posted': -6.620739651073516,
#  'postfix': -6.620739651073516,
#  'postm': -6.215274542965353,
#  'preferred': -6.620739651073516,
#  'pretty': -6.620739651073516,
#  'pricing': -5.367976682578148,
#  'prob': -6.215274542965353,
#  'processing': -5.522127362405407,
#  'product': -5.927592470513571,
#  'production': -6.620739651073516,
#  'push': -6.215274542965353,
#  'python': -5.927592470513571,
#  'question': -6.215274542965353,
#  'quot': -6.215274542965353,
#  'rcelosomers': -6.620739651073516,
#  'recommended': -6.620739651073516,
#  'rect': -6.620739651073516,
#  'reevesm': -6.620739651073516,
#  'refreshing': -6.620739651073516,
#  'rele': -6.215274542965353,
#  'request': -4.480673487577246,
#  'reubenpressm': -6.620739651073516,
#  'rketing': -5.522127362405407,
#  'rler': -6.620739651073516,
#  'rmup': -6.620739651073516,
#  'ruby': -6.215274542965353,
#  'runs': -6.620739651073516,
#  'script': -5.927592470513571,
#  'seeing': -5.704448919199361,
#  'seems': -5.704448919199361,
#  'send': -4.605836630531252,
#  'sendgrid': -4.3694478524670215,
#  'sendgrid_postb': -6.620739651073516,
#  'sending': -5.522127362405407,
#  'sengrid': -6.215274542965353,
#  'sent': -6.215274542965353,
#  'server': -5.927592470513571,
#  'service': -4.828980181845462,
#  'services': -5.927592470513571,
#  'sever': -6.215274542965353,
#  'shes': -6.620739651073516,
#  'should': -6.215274542965353,
#  'sing': -6.620739651073516,
#  'sinue': -5.927592470513571,
#  'sistem': -6.215274542965353,
#  'smtp': -4.915991558835091,
#  'some': -5.011301738639416,
#  'sons': -6.215274542965353,
#  'speed': -6.620739651073516,
#  'submit': -5.367976682578148,
#  'submitting': -4.915991558835091,
#  'supp': -5.522127362405407,
#  'switch': -5.927592470513571,
#  'switched': -6.620739651073516,
#  'sync': -6.620739651073516,
#  'system': -6.620739651073516,
#  'tegy': -5.011301738639416,
#  'tely': -6.620739651073516,
#  'templ': -4.7489374741719255,
#  'things': -6.620739651073516,
#  'this': -5.011301738639416,
#  'throttling': -6.215274542965353,
#  'tinyletter': -6.215274542965353,
#  'tion': -4.018049965629133,
#  'tips': -6.620739651073516,
#  'titt': -6.620739651073516,
#  'tives': -6.620739651073516,
#  'tried': -6.620739651073516,
#  'troubleshoot': -6.620739651073516,
#  'tsypin': -6.215274542965353,
#  'tt_pickett': -6.620739651073516,
#  'ttwdelong': -6.620739651073516,
#  'tuer': -6.620739651073516,
#  'ubuntu': -5.927592470513571,
#  'umepotier': -6.620739651073516,
#  'unifying': -5.927592470513571,
#  'unsubscribed': -6.620739651073516,
#  'unsupp': -6.620739651073516,
#  'used': -5.927592470513571,
#  'usern': -6.215274542965353,
#  'users': -6.620739651073516,
#  'using': -4.674829502018204,
#  'utom': -6.215274542965353,
#  'veled': -5.927592470513571,
#  'vero': -6.215274542965353,
#  'very': -5.927592470513571,
#  'veulent': -6.215274542965353,
#  'ving': -6.620739651073516,
#  'volume': -6.620739651073516,
#  'volumes': -6.620739651073516,
#  'wcmelb': -6.215274542965353,
#  'webhooks': -5.234445289953626,
#  'website': -6.215274542965353,
#  'week': -5.704448919199361,
#  'weer': -6.620739651073516,
#  'well': -5.927592470513571,
#  'when': -5.927592470513571,
#  'where': -5.927592470513571,
#  'which': -6.620739651073516,
#  'with': -3.676300671907076,
#  'would': -5.522127362405407,
#  'your': -4.7489374741719255,
#  'zjhok': -6.620739651073516,
#  'сервис': -6.620739651073516}

# %%
freq_b_sum = freq_b.sum()
log_prob_b = dict(np.log(freq_b/freq_b_sum))
log_prob_b
# Out:
# {'become': -6.26530121273771,
#  'been': -5.8598361046295455,
#  'behind': -6.26530121273771,
#  'best': -5.8598361046295455,
#  'bico': -6.26530121273771,
#  'body': -6.26530121273771,
#  'bouin': -6.26530121273771,
#  'bout': -5.349010480863555,
#  'brit': -6.26530121273771,
#  'burnziey': -6.26530121273771,
#  'butts': -5.8598361046295455,
#  'cccp': -6.26530121273771,
#  'ccount': -6.26530121273771,
#  'ccounts': -6.26530121273771,
#  'ccp_gu': -5.8598361046295455,
#  'ccp_m': -6.26530121273771,
#  'ccpg': -5.349010480863555,
#  'ceships': -5.8598361046295455,
#  'chful': -6.26530121273771,
#  'choice': -5.8598361046295455,
#  'chrisjboyl': -6.26530121273771,
#  'christm': -6.26530121273771,
#  'city': -6.26530121273771,
#  'cket': -6.26530121273771,
#  'ckground': -6.26530121273771,
#  'clone': -6.26530121273771,
#  'coffee': -6.26530121273771,
#  'come': -6.26530121273771,
#  'comme': -6.26530121273771,
#  'como': -5.8598361046295455,
#  'compl': -6.26530121273771,
#  'compren': -6.26530121273771,
#  'condition': -6.26530121273771,
#  'cono': -6.26530121273771,
#  'cool': -6.26530121273771,
#  'cover': -5.8598361046295455,
#  'covered': -5.8598361046295455,
#  'cruiser': -6.26530121273771,
#  'cter': -5.8598361046295455,
#  'ction': -6.26530121273771,
#  'cute': -6.26530121273771,
#  'ddition': -6.26530121273771,
#  'demigod': -6.26530121273771,
#  'dicionei': -5.8598361046295455,
#  'didn': -6.26530121273771,
#  'different': -6.26530121273771,
#  'diplom': -6.26530121273771,
#  'direct': -6.26530121273771,
#  'drill': -5.572154032177765,
#  'drunken': -6.26530121273771,
#  'effective': -6.26530121273771,
#  'elle': -6.26530121273771,
#  'entire': -6.26530121273771,
#  'entonces': -6.26530121273771,
#  'equipo': -6.26530121273771,
#  'strut': -6.26530121273771,
#  'suggestions': -6.26530121273771,
#  'supp': -6.26530121273771,
#  'surprised': -6.26530121273771,
#  'sykes': -5.8598361046295455,
#  'tchu': -6.26530121273771,
#  'technology': -6.26530121273771,
#  'tely': -6.26530121273771,
#  'thing': -5.572154032177765,
#  'this': -4.560553120499285,
#  'thisismyj': -6.26530121273771,
#  'though': -6.26530121273771,
#  'thre': -6.26530121273771,
#  'throw': -6.26530121273771,
#  'tie_phd': -6.26530121273771,
#  'tion': -5.349010480863555,
#  'tions': -6.26530121273771,
#  'tjob': -6.26530121273771,
#  'true': -6.26530121273771,
#  'tweet': -6.26530121273771,
#  'tweetfleet': -5.572154032177765,
#  'twitch': -6.26530121273771,
#  'typos': -6.26530121273771,
#  'udio': -5.8598361046295455,
#  'understood': -6.26530121273771,
#  'universe': -6.26530121273771,
#  'venido': -6.26530121273771,
#  'venue': -6.26530121273771,
#  'vicious': -6.26530121273771,
#  'vict': -6.26530121273771,
#  'video': -4.319391063682397,
#  'vidqu': -6.26530121273771,
#  'websp': -5.8598361046295455,
#  'well': -6.26530121273771,
#  'were': -5.8598361046295455,
#  'when': -5.8598361046295455,
#  'where': -5.8598361046295455,
#  'while': -6.26530121273771,
#  'whistlerbe': -5.572154032177765,
#  'whole': -6.26530121273771,
#  'will': -5.8598361046295455,
#  'wish': -6.26530121273771,
#  'with': -4.473541743509655,
#  'without': -6.26530121273771,
#  'would': -5.349010480863555,
#  'wouldn': -6.26530121273771,
#  'written': -6.26530121273771,
#  'xurs': -5.8598361046295455,
#  'yers': -6.26530121273771,
#  'ying': -5.572154032177765,
#  'your': -5.1666889240696,
#  'youtu': -3.8674059399393395,
#  'youtube': -3.8674059399393395,
#  'youtubeさんから': -5.572154032177765,
#  'yrecruit_chris': -6.26530121273771,
#  'zing': -5.572154032177765,
#  'zingb': -5.572154032177765,
#  'zomg': -6.26530121273771,
#  'zptr': -6.26530121273771,
#  'いたのはこの番組': -6.26530121273771,
#  'おしゃれだし': -6.26530121273771,
#  'が初めて': -6.26530121273771,
#  'ノが入ったファンキ': -6.26530121273771,
#  '中古盤屋でインパクトのあるジャケットを良く見かけたが音を': -6.26530121273771,
#  '少しチカ': -6.26530121273771,
#  '生演奏が熱い': -6.26530121273771,
#  '美容師さんも素敵': -6.26530121273771}

# %% [markdown]
# ##test data 가져오기

# %%
f = open("/content/drive/MyDrive/인공지능사관학교/빅데이터/03_확률 모델링_업데이트/data/tweets_test.txt","r", encoding="ms949")   # Encoding 주의!
tt = f.readlines()
f.close()
tt
# Out:
# ['Just love @Hyperionapp transactional email service - http://Hyperion.com Sorry @SendGrid and @mailjet #timetomoveon\n',
#  "@rossdeane Mind submitting a request at http://help.Hyperion.com with account details if you haven't already? Glad to take a look!\n",
#  "@veroapp Any chance you'll be adding Hyperion support to Vero?\n",
#  '@Elie__ @camj59 jparle de relai SMTP!1 million de mail chez Hyperion / mois compare a 1 million sur lite sendgrid y a pas photo avec mailjet\n',
#  'would like to send emails for welcome, password resets, payment notifications, etc. what should i use? was looking at mailgun/Hyperion\n',
#  'From Coworker about using Hyperion:  "I would entrust email handling to a Pokemon".\n',
#  '@Hyperion Realised I did that about 5 seconds after hitting send!\n',
#  'Holy shit. It’s here. http://www.Hyperion.com/ \n',
#  'Our new subscriber profile page: activity timeline, aggregate engagement stats, and Hyperion integratio #BJCBranding http://bit.ly/13waU5c \n',
#  '@Hyperionapp increases scalability ( http://bit.ly/14myVuH  ) then decreases pricing ( http://bit.ly/13uJA7s  ) #selfinducedcannibalization\n',
#  'The Beets! RT @MISSMYA: #NameAnAmazingBand Hyperion!\n',
#  'RT @LuisSand0val: Fernando Vargas Hyperion MEXICAN PRIDE MMA\n',
#  'Photo: oculi-ds: Hyperion by Natalie Manuel http://tmblr.co/ZJqANxhdSWlr \n',
#  '@Hyperion ME NEITHER!!! we can be :sadpanda: together :(\n',
#  '@Hyperion n! / ( k! * ( n! - k! ) ) where n = 5 and k = 4, it has been a long time but I think that is it\n',
#  'Megaman X - Spark Hyperion Acapella: http://youtu.be/hyx9-kWYjDI  @youtubeさんから\n',
#  '@AngelusErrare1 Storm Eagle FTW!!!, nomas no dejes que se le acerque Spark Hyperion XD\n',
#  "Gostei de um video @YouTube http://youtu.be/XzNY7zimtnI?aSpark … Hyperion's Stage on guitar (Mega Man X)\n",
#  'What is 2-year-old Hyperion, JJ, thinking in this pic? http://ow.ly/jFRqf  Re-tweet with your caption.\n',
#  '120 years of Moscow Zoo - Hyperion - Поста СССР, #postage #stamp 3347 from Soviet Union in 1984 #philately http://tinyurl.com/cguyvzb \n']

# %%
# 테스트 트윗의 유형 정보를 읽어온다 (Y_test).
f = open("/content/drive/MyDrive/인공지능사관학교/빅데이터/03_확률 모델링_업데이트/data/tweets_test_class.txt","r")
Y_test_raw = f.read()                 # 한 덩어리로 읽어온다.
Y_test = Y_test_raw.split()           # 분절을 통해서 깔끔히!
f.close()

# %% [markdown]
# ##예측 실시

# %%
Y_pred = []
for a_sentence in tt:
    log_prob_sum_a = 0.
    log_prob_sum_b = 0.
    a_sent_preprocessed = preprocessor([a_sentence])
    for a_word, a_freq in a_sent_preprocessed.items():
        if a_word in log_prob_a:
            log_prob_sum_a += log_prob_a[a_word]
        else:
            log_prob_sum_a += np.log(1.0/freq_a_sum)
            
        if a_word in log_prob_b:
            log_prob_sum_b += log_prob_b[a_word]
        else:
            log_prob_sum_b += np.log(1.0/freq_b_sum)
            
    if (log_prob_sum_a > log_prob_sum_b):
        Y_pred.append("A")
    else:
        Y_pred.append("B")

# %%
correct = pd.Series([y1==y2] for (y1,y2) in zip(Y_pred,Y_test))
print(correct)
# Out:
# 0      [True]
# 1      [True]
# 2      [True]
# 3      [True]
# 4      [True]
# 5      [True]
# 6      [True]
# 7     [False]
# 8      [True]
# 9      [True]
# 10     [True]
# 11     [True]
# 12     [True]
# 13     [True]
# 14     [True]
# 15     [True]
# 16     [True]
# 17     [True]
# 18     [True]
# 19     [True]
# dtype: object
