# %%
import os 
from google.colab import drive
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive")
#df_data = pd.read_csv()
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
# %cd '인공지능사관학교'
# Out:
# /content/drive/MyDrive/인공지능사관학교

# %%
# %cd ..
# Out:
# /content/drive/MyDrive

# %%
# %cd ..
# Out:
# /content/drive

# %%
# !ls
# Out:
# MyDrive  Shareddrives

# %%
cd ..
# Out:
# /

# %%
! ls
# Out:
# bin	 datalab  home	 lib64	opt   run   sys		       tools
# boot	 dev	  lib	 media	proc  sbin  tensorflow-1.15.2  usr
# content  etc	  lib32  mnt	root  srv   tmp		       var

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13305368 kB
# MemFree:        10520780 kB
# MemAvailable:   12482428 kB
# Buffers:           78960 kB
# Cached:          2016552 kB
# SwapCached:            0 kB
# Active:          1003924 kB
# Inactive:        1542192 kB
# Active(anon):     414232 kB
# Inactive(anon):      424 kB
# Active(file):     589692 kB
# Inactive(file):  1541768 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               584 kB
# Writeback:             0 kB
# AnonPages:        450668 kB
# Mapped:           283784 kB
# Shmem:              1140 kB
# KReclaimable:     143324 kB
# Slab:             187936 kB
# SReclaimable:     143324 kB
# SUnreclaim:        44612 kB
# KernelStack:        5392 kB
# PageTables:         6412 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6652684 kB
# Committed_AS:    3636424 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:        7896 kB
# VmallocChunk:          0 kB
# Percpu:             1400 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:       97480 kB
# DirectMap2M:     5144576 kB
# DirectMap1G:    10485760 kB

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   39G   70G  36% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# shm             5.9G     0  5.9G   0% /dev/shm
# tmpfs           6.4G   36K  6.4G   1% /var/colab
# /dev/sda1        76G   42G   35G  55% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           108G   43G   66G  40% /content/drive

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# %ls
# Out:
# bin/      datalab/  home/   lib64/  opt/   run/   sys/                tools/
# boot/     dev/      lib/    media/  proc/  sbin/  tensorflow-1.15.2/  usr/
# content/  etc/      lib32/  mnt/    root/  srv/   tmp/                var/

# %%
# %cd /content
# Out:
# /content

# %%
# %%writefile helloworld
# print("I am student")
# print(2**10)
# Out:
# Writing helloworld

# %%
# %run helloworld
# Out:
# I am student
# 1024

# %%
#%history
# %history -n 1-9
# Out:
#    1:
# import os
# from google.colab import drive
# drive.mount('/content/drive')
# os.chdir("/content/drive/My Drive")
# #df_data = pd.read_csv()
#    2: !pwd
#    3: %cd '인공지능 사관학교'
#    4: %cd '인공지능사관학교'
#    5: %cd ..
#    6: %cd..
#    7: %cd ..
#    8: !ls
#    9: cd ..

# %%
# %rerun
# Out:
# === Executing: ===
# #%history
# %history -n 1-9
# === Output: ===
#    1:
# import os
# from google.colab import drive
# drive.mount('/content/drive')
# os.chdir("/content/drive/My Drive")
# #df_data = pd.read_csv()
#    2: !pwd
#    3: %cd '인공지능 사관학교'
#    4: %cd '인공지능사관학교'
#    5: %cd ..
#    6: %cd..
#    7: %cd ..
#    8: !ls
#    9: cd ..

# %%
_
# Out:
# '/content'

# %%
__
# Out:
# '/content'

# %%
In
# Out:
# ['',
#  'import os \nfrom google.colab import drive\ndrive.mount(\'/content/drive\')\nos.chdir("/content/drive/My Drive")\n#df_data = pd.read_csv()',
#  "get_ipython().system('pwd')",
#  'get_ipython().magic("cd \'인공지능 사관학교\'")',
#  'get_ipython().magic("cd \'인공지능사관학교\'")',
#  "get_ipython().magic('cd ..')",
#  "get_ipython().magic('cd..')",
#  "get_ipython().magic('cd ..')",
#  "get_ipython().system('ls')",
#  "get_ipython().magic('cd ..')",
#  "get_ipython().magic('cd ..')",
#  "get_ipython().system(' ls')",
#  "get_ipython().system('cat /etc/issue.net')",
#  "get_ipython().system('cat /proc/cpuinfo')",
#  "get_ipython().system('cat /proc/meminfo')",
#  "get_ipython().system('python --version')",
#  "get_ipython().system('df - h')",
#  "get_ipython().system('df -h')",
#  "get_ipython().system('nvidia-smi')",
#  "get_ipython().magic('ls')",
#  "get_ipython().magic('cd /content')",
#  "get_ipython().magic('pwd ')",
#  'get_ipython().run_cell_magic(\'writefile\', \'helloworld\', \'print("I am student")\\nprint(2**10)\')',
#  "get_ipython().magic('run helloworld')",
#  "get_ipython().magic('history')",
#  "get_ipython().magic('history')\nget_ipython().magic('history -n 1 -9')",
#  "#%history\nget_ipython().magic('history -n 1 -9')",
#  "#%history\nget_ipython().magic('history -n 1-9')",
#  "get_ipython().magic('rerun')",
#  '_',
#  '__',
#  'In']

# %%
Out
# Out:
# {21: '/content',
#  29: '/content',
#  30: '/content',
#  31: ['',
#   'import os \nfrom google.colab import drive\ndrive.mount(\'/content/drive\')\nos.chdir("/content/drive/My Drive")\n#df_data = pd.read_csv()',
#   "get_ipython().system('pwd')",
#   'get_ipython().magic("cd \'인공지능 사관학교\'")',
#   'get_ipython().magic("cd \'인공지능사관학교\'")',
#   "get_ipython().magic('cd ..')",
#   "get_ipython().magic('cd..')",
#   "get_ipython().magic('cd ..')",
#   "get_ipython().system('ls')",
#   "get_ipython().magic('cd ..')",
#   "get_ipython().magic('cd ..')",
#   "get_ipython().system(' ls')",
#   "get_ipython().system('cat /etc/issue.net')",
#   "get_ipython().system('cat /proc/cpuinfo')",
#   "get_ipython().system('cat /proc/meminfo')",
#   "get_ipython().system('python --version')",
#   "get_ipython().system('df - h')",
#   "get_ipython().system('df -h')",
#   "get_ipython().system('nvidia-smi')",
#   "get_ipython().magic('ls')",
#   "get_ipython().magic('cd /content')",
#   "get_ipython().magic('pwd ')",
#   'get_ipython().run_cell_magic(\'writefile\', \'helloworld\', \'print("I am student")\\nprint(2**10)\')',
#   "get_ipython().magic('run helloworld')",
#   "get_ipython().magic('history')",
#   "get_ipython().magic('history')\nget_ipython().magic('history -n 1 -9')",
#   "#%history\nget_ipython().magic('history -n 1 -9')",
#   "#%history\nget_ipython().magic('history -n 1-9')",
#   "get_ipython().magic('rerun')",
#   '_',
#   '__',
#   'In',
#   'Out']}

# %%
# %%timeit
a = [x for x in range(100)]
# Out:
# 100000 loops, best of 5: 3.72 µs per loop

# %%
# %pwd
# Out:
# '/content'
