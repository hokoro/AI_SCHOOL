# %% [markdown]
# ### 분산분석 (ANOVA)

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# "data_ToothGrowth.csv" 사용. <br>
# len = 치아의 길이. <br>
# supp = 보조 영양제. 두 가지 타입 VC or OJ. <br>
# dose (mgr/day) = 투입양. 세 가지 0.5, 1.0, 2.0.

# %%
df = pd.read_csv('/content/drive/MyDrive/인공지능사관학교/빅데이터/05_통계와 파이썬_업데이트 V2/data/data_ToothGrowth.csv', header='infer',encoding = 'latin1')

# %%
df.head(20)
# Out:
#      len supp  dose
# 0    4.2   VC   0.5
# 1   11.5   VC   0.5
# 2    7.3   VC   0.5
# 3    5.8   VC   0.5
# 4    6.4   VC   0.5
# 5   10.0   VC   0.5
# 6   11.2   VC   0.5
# 7   11.2   VC   0.5
# 8    5.2   VC   0.5
# 9    7.0   VC   0.5
# 10  16.5   VC   1.0
# 11  16.5   VC   1.0
# 12  15.2   VC   1.0
# 13  17.3   VC   1.0
# 14  22.5   VC   1.0
# 15  17.3   VC   1.0
# 16  13.6   VC   1.0
# 17  14.5   VC   1.0
# 18  18.8   VC   1.0
# 19  15.5   VC   1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   len     60 non-null     float64
#  1   supp    60 non-null     object
#  2   dose    60 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.5+ KB

# %% [markdown]
# #### 1). 일원 ANOVA를 적용하여 supp에 의한 그룹평균 사이에 차이가 있는지 알아본다.

# %%
# supp 변수의 유형 확인.
df.supp.unique()
# Out:
# array(['VC', 'OJ'], dtype=object)

# %%
# supp 유형별 모아 둠.
y_vc = df[df.supp=='VC'].len
y_oj = df[df.supp=='OJ'].len

# %%
# 다중 상자그림 출력.
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.boxplot([y_vc,y_oj],0)
ax.set_xticklabels(['VC','OJ'])
plt.show()

# %%
sns.boxplot(x="supp", y="len", data=df)
plt.show()

# %%
# 일원 분산분석.
res=st.f_oneway(y_oj,y_vc)
print("검정통계량  : %f " % res[0] )
print("p-value   : %f " % res[1] )
# Out:
# 검정통계량  : 3.668253
# p-value   : 0.060393

# %%
# 일원 분산분석 (다른 방법).
my_model = smf.ols('len ~ supp', data = df)
my_model = my_model.fit()
sm.stats.anova_lm(my_model)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# supp       1.0   205.350000  205.350000  3.668253  0.060393
# Residual  58.0  3246.859333   55.980333       NaN       NaN

# %% [markdown]
# 그러므로, 5% 유의수준을 적용하면 그룹평균 사이에 차이가 **없다 !**

# %% [markdown]
# #### 2). 일원 ANOVA를 적용하여 dose에 의한 그룹평균 사이에 차이가 있는지 알아본다.

# %%
# dose 변수의 유형 확인.
df.dose.unique()
# Out:
# array([0.5, 1. , 2. ])

# %%
# dose 유형별 모아 둠.
x_05 = df[df.dose==0.5].len
x_1 = df[df.dose==1.0].len
x_2 = df[df.dose==2.0].len

# %%
# 다중 상자그림 출력.
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.boxplot([x_05,x_1,x_2],0)
ax.set_xticklabels(['0.5','1.0','2.0'])
plt.show()

# %%
# 일원 분산분석.
res=st.f_oneway(x_05,x_1,x_2)
print("검정통계량  : %f " % res[0] )
print("p-value   : %f " % res[1] )
# Out:
# 검정통계량  : 67.415738
# p-value   : 0.000000

# %%
# 일원 분산분석 (다른 방법).
df['dose_str'] = df.dose.astype(str)                           # 문자열 컬럼으로 변환.
my_model = smf.ols('len ~ dose_str', data = df)
my_model = my_model.fit()
sm.stats.anova_lm(my_model)
# Out:
#             df       sum_sq      mean_sq          F        PR(>F)
# dose_str   2.0  2426.434333  1213.217167  67.415738  9.532727e-16
# Residual  57.0  1025.775000    17.996053        NaN           NaN

# %% [markdown]
# 그러므로, 5% 유의수준을 적용하면 그룹평균 사이에 차이가 **있다!**
